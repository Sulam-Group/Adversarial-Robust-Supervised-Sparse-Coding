# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np
import time
import importlib

from art.attacks import FastGradientMethod, ProjectedGradientDescent, CarliniL2Method
from art.classifiers import PyTorchClassifier

# Hyper Parameters
EPOCH = 10
BATCH_SIZE = 256
LR = .5  # learning rate
MNT = 0.9   # momentum variable
DOWNLOAD_Dataset = True
N_TEST_IMG = 5
m = 256     # Dictionary Size

# parameter settings:
# m     lambda    eta
# 100   .2        .1
# 200

torch.cuda.set_device(1)
device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")

# %%
data_dir = 'data/'

def get_data_loaders(data_dir,BSize):
    
    train_data = torchvision.datasets.MNIST(
        root= data_dir,
        train=True,                                     # this is training data
        transform=torchvision.transforms.Compose([torchvision.transforms.ToTensor(),
                                  torchvision.transforms.Normalize((0.1307,), (0.3081,)),
                                 ]),    
        download=DOWNLOAD_Dataset,                        # download it if you don't have it
    )
    # Data Loader for easy mini-batch return in training, the image batch shape will be (50, 1, 28, 28)
    train_loader = torch.utils.data.DataLoader(dataset=train_data, batch_size=BSize, shuffle=True)

    test_data = torchvision.datasets.MNIST(
        root= data_dir,
        train=False,                                     # this is testing data
        transform=torchvision.transforms.Compose([torchvision.transforms.ToTensor(),
                                  torchvision.transforms.Normalize((0.1307,), (0.3081,)),
                                 ]),
        download=DOWNLOAD_Dataset,                        # download it if you don't have it
    )
    test_loader = torch.utils.data.DataLoader(dataset=test_data, batch_size=BSize, shuffle=True)
    
    return train_loader, test_loader


def preprocess(x):
    x = x.view(-1, 28*28).t()
    ms = torch.mean(x,dim=0)
    x = x - ms
    x = modelDL.NormDict(x).t()
    return x

# %%
import sparse_learnable_dictionary as modelDL

train_loader, test_loader = get_data_loaders(data_dir,BATCH_SIZE)

# %% [markdown]
# ### First unsupervised training

# %%
import importlib
importlib.reload(modelDL)

# Training
Error = np.zeros((EPOCH,))
Nnz = np.zeros((EPOCH,))
Loss = np.zeros((EPOCH,))
N = len(train_loader.dataset)
DISPLAY_FREQ = 1 ;
TSHOW = np.round(DISPLAY_FREQ * N/BATCH_SIZE) # times per EPOCH to display information
t0 = time.perf_counter()
SC = 'fista' # 'fista' or 'IHT'
lambd = .04       # sparsity parameter: float numer if 'fista' or cardinality constraint if 'IHT'

model = modelDL.DictLearn(m,SC,lambd).to(device)
# optimizer = torch.optim.SGD(model.parameters(), lr=.001, momentum=.9)
optimizer = torch.optim.Adam(model.parameters())
loss_func = nn.MSELoss()

Err = []

# %%
# model.double()

for epoch in range(EPOCH):
    for step, (x, y) in enumerate(train_loader):
        b_x = preprocess(x).to(device).type(model.W.type())  # batch x, shape (batch, 28*28)
        b_y = preprocess(x).to(device).type(model.W.type())     # batch y, shape (batch, 28*28)
        b_label = (y).to(device)               # batch label

        decoded, encoded, errIHT = model(b_x)
        
        loss = loss_func(decoded, b_y)      # mean square error
#         loss = 1/len(b_label) * torch.norm(b_x-b_y)**2
        optimizer.zero_grad()               # clear gradients for this training step
        loss.backward()                     # backpropagation, compute gradients
        optimizer.step()                    # apply gradients
        model.zero_grad()
        model.normalize()
        
        
        if SC == 'IHT': Loss[epoch] = Loss[epoch] + loss.data
        elif SC == 'fista': Loss[epoch] = Loss[epoch] + loss.data + lambd * np.sum(np.abs(encoded.detach().cpu().numpy()))
        
        decoded = decoded.detach()
        err = np.linalg.norm( (decoded-b_x).cpu().numpy() ,'fro') / np.linalg.norm( b_x.cpu().numpy() ,'fro')
        Error[epoch] = Error[epoch] + errIHT[-1]
        Err = np.append(Err,errIHT[-1])
        Nnz[epoch] = Nnz[epoch] + np.count_nonzero(encoded.detach().cpu().numpy())/encoded.detach().cpu().numpy().size
#         print('Density: %.3f' % (np.count_nonzero(encoded.detach().cpu().numpy())/ BATCH_SIZE))
        
#         # for debugging:
#         print(Error[epoch]/(step+1))
#         if step%50==0:
#             plt.plot(errIHT); plt.show()
        
    Loss[epoch] /= len(train_loader.dataset)
    Error[epoch] /= (step+1)
    Nnz[epoch] /= (step+1)
    print('Epoch: ', epoch, ', Error: ', Error[epoch], ', | train loss: %.3e' % Loss[epoch], ' NNZ/sample: ', Nnz[epoch] )
    

model_unsup = model
# Out:
# Epoch:  0 , Error:  0.4693925463138743 , | train loss: 8.933e-02  NNZ/sample:  0.24151113523659132
# Epoch:  1 , Error:  0.3572741798898007 , | train loss: 7.810e-02  NNZ/sample:  0.16513018236092644
# Epoch:  2 , Error:  0.34364126096380515 , | train loss: 7.466e-02  NNZ/sample:  0.151573949502715
# Epoch:  3 , Error:  0.336313485084696 , | train loss: 7.320e-02  NNZ/sample:  0.14440119317237368
# Epoch:  4 , Error:  0.3319753549200423 , | train loss: 7.237e-02  NNZ/sample:  0.1400006449814384
# Epoch:  5 , Error:  0.32922617894537903 , | train loss: 7.187e-02  NNZ/sample:  0.13710069588735596
# Epoch:  6 , Error:  0.3273649388171257 , | train loss: 7.152e-02  NNZ/sample:  0.13507071420656028
# Epoch:  7 , Error:  0.3260986863298619 , | train loss: 7.130e-02  NNZ/sample:  0.13356641404172206
# Epoch:  8 , Error:  0.3255202035954658 , | train loss: 7.112e-02  NNZ/sample:  0.1327158177152593
# Epoch:  9 , Error:  0.3253397084297018 , | train loss: 7.095e-02  NNZ/sample:  0.13194547612616356

# %%
plt.style.use('ggplot')

plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.plot(Err); plt.title('Reconstruction Error'); plt.xlabel('mini-bach / dict update');
plt.subplot(1,2,2)
plt.plot(Loss); plt.title('Loss Evolution'); plt.xlabel('epoch')
plt.show(); 

from skimage import data, color
from skimage.transform import rescale, resize, downscale_local_mean
    
W = model_unsup.cpu().W.data.numpy().copy()
nat = int(np.floor(np.sqrt(m)))
M1 = modelDL.showFilters(W,nat,nat)
plt.figure(figsize=(5,5))
plt.imshow(rescale(M1,4,mode='constant'),cmap='gray')
plt.axis('off')
plt.show()
# Out:
# /home/jere/anaconda3/lib/python3.7/site-packages/skimage/transform/_warps.py:23: UserWarning: The default multichannel argument (None) is deprecated.  Please specify either True or False explicitly.  multichannel will default to False starting with release 0.16.
#   warn('The default multichannel argument (None) is deprecated.  Please '

# %% [markdown]
# ### Supervised Training

# %%
# Initialize
importlib.reload(modelDL)

BATCH_SIZE = 64
SC = 'fista' # 'fista' or 'IHT'
LMDS = torch.Tensor([.05, .05, .1, .1, .1, .15, .15, .15, .15, .2, .2, .2, .2]).to(device)
EPOCH = 40

train_loader, test_loader = get_data_loaders(data_dir,BATCH_SIZE)

model = modelDL.DictLearn_supervised(m,SC).to(device)
optimizer = torch.optim.Adam(model.parameters(),lr=0.001,betas=(0.9, 0.9))
# optimizer = torch.optim.SGD(model.parameters(), lr=.02, momentum=.9)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=9, gamma=0.7)

# optimizer = torch.optim.SGD([
# 	{'params': model.W.parameters(), 'lr': 0.0}], lr=0.01, momentum=0.9, nesterov=True)


loss_func = nn.CrossEntropyLoss()

Using_Unsupervised_Dictionary_as_Init = True

if Using_Unsupervised_Dictionary_as_Init:
    model.init_dictionary(model_unsup.W)

Loss_sup = []
accuracy_train = []
accuracy_test = []
nnz = []

eta1 = 100
eta2 = .01

import time

# %%
I = torch.Tensor(np.eye(m)).type(model.W.type()).to(device)

# settings things up
model.learn_flag = True
model.float().to(device)

for epoch in range(EPOCH):
    
    model.lambd = nn.Parameter(LMDS[min(epoch,len(LMDS)-1)])
    
    for step, (x, y) in enumerate(train_loader):
        b_x = preprocess(x).to(device).type(model.W.type())
        b_label = (y).to(device)            # batch label

        out = model(b_x)
        
        Lclass = loss_func(out, b_label)
        Ldict = 1/m * torch.norm(I - torch.matmul(model.W.t() , model.W))**2
        Lw = 1/m * torch.norm(model.Wclass.weight)**2
        loss = Lclass + eta1*Ldict  + eta2*Lw 
        
        optimizer.zero_grad()               # clear gradients for this training step
        loss.backward()                     # backpropagation, compute gradients
        optimizer.step()                    # apply gradients
        model.zero_grad()
        model.normalize()
        
        Loss_sup = np.append(Loss_sup,loss.data)
        acc = torch.sum(torch.argmax(out, dim=1) == b_label).cpu().numpy() / len(b_label)
        accuracy_train = np.append(accuracy_train,acc)
        nnz = np.append(nnz,model.last_avg_nnz)
        
        if step % 10 == 0: # validate accuracy
            t = time.time()
            acc = 0
            for cnt, (x, y) in enumerate(test_loader):
                b_x = preprocess(x).to(device).type(model.W.type())
                b_label = (y).to(device)           # batch label

                out = model(b_x)

                acc += torch.sum(torch.argmax(out, dim=1) == b_label).cpu().numpy()
            
            elapsed = time.time() - t
            accuracy_test = np.append(accuracy_test,acc / len(test_loader.dataset))
            print('Epc/stp: %d/%d'%(epoch+1,step),'| Lmd = %.2f'%model.lambd,'| Loss: %.3f'%np.mean(Loss_sup[-20:-1]),
                  ' | nnz: %.2f' % nnz[-1],'| train acc.: %.2f' % accuracy_train[-1] , '| test acc: %.2f' % accuracy_test[-1],
                  ' | mu: %.4f'% modelDL.get_mu(model),' | Cw: %.4f'% modelDL.get_ClassifierConstant(model),'| T/I = %.2f'%elapsed)

        
    scheduler.step()
        
# Done training - change to exact Lasso solution
model.learn_flag = False
# Out:
# /home/jere/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/jere/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Epc/stp: 1/0 | Lmd = 0.05 | Loss: nan  | nnz: 45.36 | train acc.: 0.06 | test acc: 0.09  | mu: 0.7781  | Cw: 0.8818 | T/I = 3.61
# Epc/stp: 1/10 | Lmd = 0.05 | Loss: 577.360  | nnz: 40.16 | train acc.: 0.20 | test acc: 0.13  | mu: 0.7332  | Cw: 0.8989 | T/I = 3.61
# Epc/stp: 1/20 | Lmd = 0.05 | Loss: 448.010  | nnz: 51.16 | train acc.: 0.12 | test acc: 0.17  | mu: 0.6924  | Cw: 0.9249 | T/I = 3.62
# Epc/stp: 1/30 | Lmd = 0.05 | Loss: 309.700  | nnz: 53.86 | train acc.: 0.25 | test acc: 0.27  | mu: 0.6437  | Cw: 0.9599 | T/I = 3.64
# Epc/stp: 1/40 | Lmd = 0.05 | Loss: 239.457  | nnz: 51.41 | train acc.: 0.36 | test acc: 0.41  | mu: 0.5878  | Cw: 1.0055 | T/I = 3.60
# Epc/stp: 1/50 | Lmd = 0.05 | Loss: 187.393  | nnz: 49.02 | train acc.: 0.48 | test acc: 0.54  | mu: 0.5257  | Cw: 1.0656 | T/I = 3.63
# Epc/stp: 1/60 | Lmd = 0.05 | Loss: 146.263  | nnz: 54.77 | train acc.: 0.53 | test acc: 0.62  | mu: 0.4712  | Cw: 1.1458 | T/I = 3.61
# Epc/stp: 1/70 | Lmd = 0.05 | Loss: 109.426  | nnz: 58.39 | train acc.: 0.66 | test acc: 0.66  | mu: 0.4082  | Cw: 1.2372 | T/I = 3.61
# Epc/stp: 1/80 | Lmd = 0.05 | Loss: 75.310  | nnz: 64.98 | train acc.: 0.64 | test acc: 0.69  | mu: 0.3315  | Cw: 1.3364 | T/I = 3.61
# Epc/stp: 1/90 | Lmd = 0.05 | Loss: 45.261  | nnz: 73.03 | train acc.: 0.56 | test acc: 0.71  | mu: 0.2601  | Cw: 1.4390 | T/I = 3.61
# Epc/stp: 1/100 | Lmd = 0.05 | Loss: 22.056  | nnz: 75.64 | train acc.: 0.69 | test acc: 0.74  | mu: 0.1613  | Cw: 1.5473 | T/I = 3.60
# Epc/stp: 1/110 | Lmd = 0.05 | Loss: 8.263  | nnz: 77.17 | train acc.: 0.80 | test acc: 0.76  | mu: 0.0486  | Cw: 1.6596 | T/I = 3.61
# Epc/stp: 1/120 | Lmd = 0.05 | Loss: 3.526  | nnz: 78.77 | train acc.: 0.67 | test acc: 0.77  | mu: 0.0569  | Cw: 1.7710 | T/I = 3.61
# Epc/stp: 1/130 | Lmd = 0.05 | Loss: 2.853  | nnz: 74.66 | train acc.: 0.70 | test acc: 0.78  | mu: 0.0388  | Cw: 1.8888 | T/I = 3.62
# Epc/stp: 1/140 | Lmd = 0.05 | Loss: 2.477  | nnz: 77.38 | train acc.: 0.75 | test acc: 0.78  | mu: 0.0191  | Cw: 2.0099 | T/I = 3.62
# Epc/stp: 1/150 | Lmd = 0.05 | Loss: 2.260  | nnz: 75.61 | train acc.: 0.80 | test acc: 0.79  | mu: 0.0156  | Cw: 2.1328 | T/I = 3.65
# Epc/stp: 1/160 | Lmd = 0.05 | Loss: 2.177  | nnz: 78.67 | train acc.: 0.83 | test acc: 0.80  | mu: 0.0124  | Cw: 2.2593 | T/I = 3.63
# Epc/stp: 1/170 | Lmd = 0.05 | Loss: 2.149  | nnz: 72.56 | train acc.: 0.81 | test acc: 0.82  | mu: 0.0157  | Cw: 2.3927 | T/I = 3.63
# Epc/stp: 1/180 | Lmd = 0.05 | Loss: 2.108  | nnz: 74.97 | train acc.: 0.81 | test acc: 0.83  | mu: 0.0071  | Cw: 2.5386 | T/I = 3.65
# Epc/stp: 1/190 | Lmd = 0.05 | Loss: 2.072  | nnz: 71.41 | train acc.: 0.86 | test acc: 0.84  | mu: 0.0091  | Cw: 2.6823 | T/I = 3.62
# Epc/stp: 1/200 | Lmd = 0.05 | Loss: 2.069  | nnz: 73.80 | train acc.: 0.83 | test acc: 0.84  | mu: 0.0138  | Cw: 2.8250 | T/I = 3.63
# Epc/stp: 1/210 | Lmd = 0.05 | Loss: 2.056  | nnz: 75.00 | train acc.: 0.78 | test acc: 0.85  | mu: 0.0082  | Cw: 2.9763 | T/I = 3.61
# Epc/stp: 1/220 | Lmd = 0.05 | Loss: 2.014  | nnz: 72.45 | train acc.: 0.83 | test acc: 0.85  | mu: 0.0058  | Cw: 3.1335 | T/I = 3.61
# Epc/stp: 1/230 | Lmd = 0.05 | Loss: 1.999  | nnz: 77.09 | train acc.: 0.81 | test acc: 0.85  | mu: 0.0106  | Cw: 3.2879 | T/I = 3.62
# Epc/stp: 1/240 | Lmd = 0.05 | Loss: 2.013  | nnz: 72.42 | train acc.: 0.88 | test acc: 0.85  | mu: 0.0085  | Cw: 3.4409 | T/I = 3.63
# Epc/stp: 1/250 | Lmd = 0.05 | Loss: 1.971  | nnz: 71.47 | train acc.: 0.83 | test acc: 0.85  | mu: 0.0070  | Cw: 3.5927 | T/I = 3.62
# Epc/stp: 1/260 | Lmd = 0.05 | Loss: 1.920  | nnz: 71.48 | train acc.: 0.86 | test acc: 0.85  | mu: 0.0077  | Cw: 3.7461 | T/I = 3.61
# Epc/stp: 1/270 | Lmd = 0.05 | Loss: 1.906  | nnz: 72.39 | train acc.: 0.83 | test acc: 0.85  | mu: 0.0069  | Cw: 3.9029 | T/I = 3.61
# Epc/stp: 1/280 | Lmd = 0.05 | Loss: 1.887  | nnz: 72.59 | train acc.: 0.86 | test acc: 0.86  | mu: 0.0064  | Cw: 4.0622 | T/I = 3.61
# Epc/stp: 1/290 | Lmd = 0.05 | Loss: 1.873  | nnz: 68.53 | train acc.: 0.84 | test acc: 0.86  | mu: 0.0080  | Cw: 4.2234 | T/I = 3.61
# Epc/stp: 1/300 | Lmd = 0.05 | Loss: 1.866  | nnz: 69.55 | train acc.: 0.84 | test acc: 0.86  | mu: 0.0090  | Cw: 4.3870 | T/I = 3.61
# Epc/stp: 1/310 | Lmd = 0.05 | Loss: 1.847  | nnz: 69.89 | train acc.: 0.84 | test acc: 0.86  | mu: 0.0079  | Cw: 4.5501 | T/I = 3.60
# Epc/stp: 1/320 | Lmd = 0.05 | Loss: 1.821  | nnz: 72.31 | train acc.: 0.78 | test acc: 0.86  | mu: 0.0091  | Cw: 4.7122 | T/I = 3.61
# Epc/stp: 1/330 | Lmd = 0.05 | Loss: 1.805  | nnz: 73.36 | train acc.: 0.91 | test acc: 0.86  | mu: 0.0090  | Cw: 4.8791 | T/I = 3.61
# Epc/stp: 1/340 | Lmd = 0.05 | Loss: 1.789  | nnz: 72.55 | train acc.: 0.80 | test acc: 0.86  | mu: 0.0067  | Cw: 5.0459 | T/I = 3.61
# Epc/stp: 1/350 | Lmd = 0.05 | Loss: 1.787  | nnz: 70.97 | train acc.: 0.92 | test acc: 0.86  | mu: 0.0138  | Cw: 5.2114 | T/I = 3.62
# Epc/stp: 1/360 | Lmd = 0.05 | Loss: 1.834  | nnz: 71.86 | train acc.: 0.83 | test acc: 0.86  | mu: 0.0203  | Cw: 5.3746 | T/I = 3.61
# Epc/stp: 1/370 | Lmd = 0.05 | Loss: 1.797  | nnz: 70.86 | train acc.: 0.94 | test acc: 0.86  | mu: 0.0098  | Cw: 5.5334 | T/I = 3.64
# Epc/stp: 1/380 | Lmd = 0.05 | Loss: 1.713  | nnz: 68.53 | train acc.: 0.91 | test acc: 0.86  | mu: 0.0129  | Cw: 5.6870 | T/I = 3.63
# Epc/stp: 1/390 | Lmd = 0.05 | Loss: 1.726  | nnz: 69.78 | train acc.: 0.88 | test acc: 0.86  | mu: 0.0155  | Cw: 5.8421 | T/I = 3.62
# Epc/stp: 1/400 | Lmd = 0.05 | Loss: 1.713  | nnz: 74.48 | train acc.: 0.78 | test acc: 0.86  | mu: 0.0089  | Cw: 5.9988 | T/I = 3.62
# Epc/stp: 1/410 | Lmd = 0.05 | Loss: 1.669  | nnz: 73.39 | train acc.: 0.84 | test acc: 0.86  | mu: 0.0095  | Cw: 6.1628 | T/I = 3.62
# Epc/stp: 1/420 | Lmd = 0.05 | Loss: 1.639  | nnz: 67.14 | train acc.: 0.91 | test acc: 0.86  | mu: 0.0089  | Cw: 6.3303 | T/I = 3.62
# Epc/stp: 1/430 | Lmd = 0.05 | Loss: 1.645  | nnz: 72.44 | train acc.: 0.91 | test acc: 0.87  | mu: 0.0103  | Cw: 6.4924 | T/I = 3.64
# Epc/stp: 1/440 | Lmd = 0.05 | Loss: 1.636  | nnz: 73.55 | train acc.: 0.83 | test acc: 0.87  | mu: 0.0077  | Cw: 6.6567 | T/I = 3.64
# Epc/stp: 1/450 | Lmd = 0.05 | Loss: 1.602  | nnz: 68.84 | train acc.: 0.84 | test acc: 0.87  | mu: 0.0124  | Cw: 6.8170 | T/I = 3.64
# Epc/stp: 1/460 | Lmd = 0.05 | Loss: 1.594  | nnz: 70.98 | train acc.: 0.72 | test acc: 0.87  | mu: 0.0116  | Cw: 6.9753 | T/I = 3.61
# Epc/stp: 1/470 | Lmd = 0.05 | Loss: 1.611  | nnz: 68.91 | train acc.: 0.88 | test acc: 0.87  | mu: 0.0081  | Cw: 7.1302 | T/I = 3.63
# Epc/stp: 1/480 | Lmd = 0.05 | Loss: 1.572  | nnz: 72.12 | train acc.: 0.86 | test acc: 0.87  | mu: 0.0072  | Cw: 7.2891 | T/I = 3.62
# Epc/stp: 1/490 | Lmd = 0.05 | Loss: 1.523  | nnz: 71.75 | train acc.: 0.95 | test acc: 0.87  | mu: 0.0090  | Cw: 7.4498 | T/I = 3.66
# Epc/stp: 1/500 | Lmd = 0.05 | Loss: 1.530  | nnz: 72.56 | train acc.: 0.84 | test acc: 0.87  | mu: 0.0103  | Cw: 7.6123 | T/I = 3.64
# Epc/stp: 1/510 | Lmd = 0.05 | Loss: 1.543  | nnz: 68.94 | train acc.: 0.95 | test acc: 0.87  | mu: 0.0104  | Cw: 7.7718 | T/I = 3.64
# Epc/stp: 1/520 | Lmd = 0.05 | Loss: 1.512  | nnz: 71.28 | train acc.: 0.75 | test acc: 0.87  | mu: 0.0135  | Cw: 7.9269 | T/I = 3.61
# Epc/stp: 1/530 | Lmd = 0.05 | Loss: 1.541  | nnz: 68.72 | train acc.: 0.84 | test acc: 0.87  | mu: 0.0158  | Cw: 8.0813 | T/I = 3.64
# Epc/stp: 1/540 | Lmd = 0.05 | Loss: 1.512  | nnz: 69.45 | train acc.: 0.84 | test acc: 0.87  | mu: 0.0099  | Cw: 8.2439 | T/I = 3.62
# Epc/stp: 1/550 | Lmd = 0.05 | Loss: 1.435  | nnz: 70.44 | train acc.: 0.88 | test acc: 0.87  | mu: 0.0088  | Cw: 8.4093 | T/I = 3.63
# Epc/stp: 1/560 | Lmd = 0.05 | Loss: 1.424  | nnz: 70.45 | train acc.: 0.83 | test acc: 0.88  | mu: 0.0124  | Cw: 8.5733 | T/I = 3.60
# Epc/stp: 1/570 | Lmd = 0.05 | Loss: 1.462  | nnz: 68.41 | train acc.: 0.83 | test acc: 0.87  | mu: 0.0154  | Cw: 8.7331 | T/I = 3.61
# Epc/stp: 1/580 | Lmd = 0.05 | Loss: 1.441  | nnz: 73.39 | train acc.: 0.89 | test acc: 0.87  | mu: 0.0138  | Cw: 8.8941 | T/I = 3.61
# Epc/stp: 1/590 | Lmd = 0.05 | Loss: 1.396  | nnz: 70.08 | train acc.: 0.92 | test acc: 0.88  | mu: 0.0107  | Cw: 9.0543 | T/I = 3.60
# Epc/stp: 1/600 | Lmd = 0.05 | Loss: 1.395  | nnz: 71.09 | train acc.: 0.88 | test acc: 0.88  | mu: 0.0104  | Cw: 9.2133 | T/I = 3.60
# Epc/stp: 1/610 | Lmd = 0.05 | Loss: 1.385  | nnz: 67.98 | train acc.: 0.86 | test acc: 0.88  | mu: 0.0080  | Cw: 9.3772 | T/I = 3.61
# Epc/stp: 1/620 | Lmd = 0.05 | Loss: 1.354  | nnz: 70.50 | train acc.: 0.88 | test acc: 0.88  | mu: 0.0133  | Cw: 9.5430 | T/I = 3.61
# Epc/stp: 1/630 | Lmd = 0.05 | Loss: 1.414  | nnz: 69.44 | train acc.: 0.91 | test acc: 0.88  | mu: 0.0188  | Cw: 9.7041 | T/I = 3.61
# Epc/stp: 1/640 | Lmd = 0.05 | Loss: 1.416  | nnz: 72.75 | train acc.: 0.89 | test acc: 0.88  | mu: 0.0120  | Cw: 9.8615 | T/I = 3.61
# Epc/stp: 1/650 | Lmd = 0.05 | Loss: 1.338  | nnz: 69.64 | train acc.: 0.86 | test acc: 0.88  | mu: 0.0103  | Cw: 10.0216 | T/I = 3.61
# Epc/stp: 1/660 | Lmd = 0.05 | Loss: 1.320  | nnz: 71.55 | train acc.: 0.77 | test acc: 0.88  | mu: 0.0087  | Cw: 10.1773 | T/I = 3.60
# Epc/stp: 1/670 | Lmd = 0.05 | Loss: 1.296  | nnz: 71.23 | train acc.: 0.86 | test acc: 0.88  | mu: 0.0094  | Cw: 10.3352 | T/I = 3.61
# Epc/stp: 1/680 | Lmd = 0.05 | Loss: 1.378  | nnz: 72.25 | train acc.: 0.91 | test acc: 0.88  | mu: 0.0200  | Cw: 10.4873 | T/I = 3.63
# Epc/stp: 1/690 | Lmd = 0.05 | Loss: 1.496  | nnz: 70.03 | train acc.: 0.91 | test acc: 0.89  | mu: 0.0148  | Cw: 10.6408 | T/I = 3.61
# Epc/stp: 1/700 | Lmd = 0.05 | Loss: 1.344  | nnz: 70.56 | train acc.: 0.91 | test acc: 0.89  | mu: 0.0124  | Cw: 10.7931 | T/I = 3.61
# Epc/stp: 1/710 | Lmd = 0.05 | Loss: 1.261  | nnz: 70.80 | train acc.: 0.83 | test acc: 0.89  | mu: 0.0186  | Cw: 10.9507 | T/I = 3.61
# Epc/stp: 1/720 | Lmd = 0.05 | Loss: 1.312  | nnz: 72.36 | train acc.: 0.84 | test acc: 0.89  | mu: 0.0336  | Cw: 11.1062 | T/I = 3.62
# Epc/stp: 1/730 | Lmd = 0.05 | Loss: 1.284  | nnz: 73.00 | train acc.: 0.86 | test acc: 0.89  | mu: 0.0269  | Cw: 11.2649 | T/I = 3.64
# Epc/stp: 1/740 | Lmd = 0.05 | Loss: 1.234  | nnz: 67.52 | train acc.: 0.86 | test acc: 0.89  | mu: 0.0459  | Cw: 11.4196 | T/I = 3.63
# Epc/stp: 1/750 | Lmd = 0.05 | Loss: 1.449  | nnz: 69.77 | train acc.: 0.88 | test acc: 0.89  | mu: 0.0634  | Cw: 11.5710 | T/I = 3.63
# Epc/stp: 1/760 | Lmd = 0.05 | Loss: 1.544  | nnz: 68.03 | train acc.: 0.88 | test acc: 0.89  | mu: 0.0624  | Cw: 11.7222 | T/I = 3.61
# Epc/stp: 1/770 | Lmd = 0.05 | Loss: 1.314  | nnz: 70.58 | train acc.: 0.88 | test acc: 0.89  | mu: 0.0241  | Cw: 11.8723 | T/I = 3.62
# Epc/stp: 1/780 | Lmd = 0.05 | Loss: 1.239  | nnz: 70.97 | train acc.: 0.86 | test acc: 0.89  | mu: 0.0403  | Cw: 12.0202 | T/I = 3.60
# Epc/stp: 1/790 | Lmd = 0.05 | Loss: 1.213  | nnz: 70.41 | train acc.: 0.89 | test acc: 0.90  | mu: 0.0202  | Cw: 12.1646 | T/I = 3.60
# Epc/stp: 1/800 | Lmd = 0.05 | Loss: 1.141  | nnz: 72.42 | train acc.: 0.75 | test acc: 0.90  | mu: 0.0218  | Cw: 12.3161 | T/I = 3.60
# Epc/stp: 1/810 | Lmd = 0.05 | Loss: 1.135  | nnz: 65.88 | train acc.: 0.84 | test acc: 0.90  | mu: 0.0150  | Cw: 12.4705 | T/I = 3.61
# Epc/stp: 1/820 | Lmd = 0.05 | Loss: 1.152  | nnz: 73.22 | train acc.: 0.86 | test acc: 0.90  | mu: 0.0329  | Cw: 12.6252 | T/I = 3.61
# Epc/stp: 1/830 | Lmd = 0.05 | Loss: 1.238  | nnz: 73.41 | train acc.: 0.86 | test acc: 0.90  | mu: 0.0649  | Cw: 12.7790 | T/I = 3.60
# Epc/stp: 1/840 | Lmd = 0.05 | Loss: 1.331  | nnz: 68.64 | train acc.: 0.88 | test acc: 0.90  | mu: 0.0759  | Cw: 12.9305 | T/I = 3.61
# Epc/stp: 1/850 | Lmd = 0.05 | Loss: 1.223  | nnz: 69.03 | train acc.: 0.91 | test acc: 0.89  | mu: 0.0326  | Cw: 13.0816 | T/I = 3.61
# Epc/stp: 1/860 | Lmd = 0.05 | Loss: 1.057  | nnz: 70.17 | train acc.: 0.81 | test acc: 0.89  | mu: 0.0235  | Cw: 13.2351 | T/I = 3.60
# Epc/stp: 1/870 | Lmd = 0.05 | Loss: 1.034  | nnz: 71.56 | train acc.: 0.89 | test acc: 0.90  | mu: 0.0209  | Cw: 13.3841 | T/I = 3.61
# Epc/stp: 1/880 | Lmd = 0.05 | Loss: 1.120  | nnz: 70.67 | train acc.: 0.88 | test acc: 0.90  | mu: 0.0258  | Cw: 13.5251 | T/I = 3.60
# Epc/stp: 1/890 | Lmd = 0.05 | Loss: 1.141  | nnz: 69.56 | train acc.: 0.86 | test acc: 0.90  | mu: 0.0393  | Cw: 13.6691 | T/I = 3.60
# Epc/stp: 1/900 | Lmd = 0.05 | Loss: 1.041  | nnz: 72.20 | train acc.: 0.89 | test acc: 0.90  | mu: 0.0213  | Cw: 13.8124 | T/I = 3.60
# Epc/stp: 1/910 | Lmd = 0.05 | Loss: 1.053  | nnz: 71.27 | train acc.: 0.91 | test acc: 0.90  | mu: 0.0348  | Cw: 13.9515 | T/I = 3.63
# Epc/stp: 1/920 | Lmd = 0.05 | Loss: 1.102  | nnz: 69.25 | train acc.: 0.92 | test acc: 0.90  | mu: 0.0378  | Cw: 14.0879 | T/I = 3.60
# Epc/stp: 1/930 | Lmd = 0.05 | Loss: 1.092  | nnz: 68.67 | train acc.: 0.89 | test acc: 0.90  | mu: 0.0172  | Cw: 14.2372 | T/I = 3.60
# Epc/stp: 2/0 | Lmd = 0.05 | Loss: 1.066  | nnz: 69.84 | train acc.: 0.84 | test acc: 0.90  | mu: 0.0183  | Cw: 14.3481 | T/I = 3.61
# Epc/stp: 2/10 | Lmd = 0.05 | Loss: 1.049  | nnz: 71.36 | train acc.: 0.91 | test acc: 0.90  | mu: 0.0168  | Cw: 14.4802 | T/I = 3.61
# Epc/stp: 2/20 | Lmd = 0.05 | Loss: 1.002  | nnz: 70.94 | train acc.: 0.86 | test acc: 0.90  | mu: 0.0151  | Cw: 14.6142 | T/I = 3.62
# Epc/stp: 2/30 | Lmd = 0.05 | Loss: 1.023  | nnz: 69.53 | train acc.: 0.89 | test acc: 0.90  | mu: 0.0183  | Cw: 14.7548 | T/I = 3.60
# Epc/stp: 2/40 | Lmd = 0.05 | Loss: 1.084  | nnz: 66.53 | train acc.: 0.91 | test acc: 0.90  | mu: 0.0193  | Cw: 14.8987 | T/I = 3.60
# Epc/stp: 2/50 | Lmd = 0.05 | Loss: 1.072  | nnz: 69.39 | train acc.: 0.92 | test acc: 0.91  | mu: 0.0188  | Cw: 15.0461 | T/I = 3.61
# Epc/stp: 2/60 | Lmd = 0.05 | Loss: 1.020  | nnz: 68.20 | train acc.: 0.91 | test acc: 0.91  | mu: 0.0145  | Cw: 15.1942 | T/I = 3.60
# Epc/stp: 2/70 | Lmd = 0.05 | Loss: 0.985  | nnz: 70.39 | train acc.: 0.91 | test acc: 0.91  | mu: 0.0154  | Cw: 15.3356 | T/I = 3.60
# Epc/stp: 2/80 | Lmd = 0.05 | Loss: 0.999  | nnz: 71.47 | train acc.: 0.89 | test acc: 0.91  | mu: 0.0245  | Cw: 15.4748 | T/I = 3.62
# Epc/stp: 2/90 | Lmd = 0.05 | Loss: 1.069  | nnz: 68.33 | train acc.: 0.86 | test acc: 0.91  | mu: 0.0249  | Cw: 15.6137 | T/I = 3.60
# Epc/stp: 2/100 | Lmd = 0.05 | Loss: 1.083  | nnz: 69.84 | train acc.: 0.94 | test acc: 0.91  | mu: 0.0176  | Cw: 15.7516 | T/I = 3.65
# Epc/stp: 2/110 | Lmd = 0.05 | Loss: 1.008  | nnz: 71.38 | train acc.: 0.83 | test acc: 0.91  | mu: 0.0127  | Cw: 15.8918 | T/I = 3.60
# Epc/stp: 2/120 | Lmd = 0.05 | Loss: 0.971  | nnz: 72.58 | train acc.: 0.88 | test acc: 0.91  | mu: 0.0116  | Cw: 16.0223 | T/I = 3.60
# Epc/stp: 2/130 | Lmd = 0.05 | Loss: 0.925  | nnz: 72.59 | train acc.: 0.97 | test acc: 0.91  | mu: 0.0079  | Cw: 16.1547 | T/I = 3.65
# Epc/stp: 2/140 | Lmd = 0.05 | Loss: 0.899  | nnz: 70.19 | train acc.: 0.92 | test acc: 0.91  | mu: 0.0104  | Cw: 16.2911 | T/I = 3.60
# Epc/stp: 2/150 | Lmd = 0.05 | Loss: 0.896  | nnz: 73.86 | train acc.: 0.86 | test acc: 0.91  | mu: 0.0097  | Cw: 16.4250 | T/I = 3.60
# Epc/stp: 2/160 | Lmd = 0.05 | Loss: 1.031  | nnz: 71.58 | train acc.: 0.91 | test acc: 0.91  | mu: 0.0232  | Cw: 16.5549 | T/I = 3.63
# Epc/stp: 2/170 | Lmd = 0.05 | Loss: 1.107  | nnz: 70.75 | train acc.: 0.89 | test acc: 0.91  | mu: 0.0185  | Cw: 16.6832 | T/I = 3.64
# Epc/stp: 2/180 | Lmd = 0.05 | Loss: 0.968  | nnz: 71.48 | train acc.: 0.89 | test acc: 0.91  | mu: 0.0162  | Cw: 16.8091 | T/I = 3.62
# Epc/stp: 2/190 | Lmd = 0.05 | Loss: 0.924  | nnz: 71.73 | train acc.: 0.92 | test acc: 0.91  | mu: 0.0213  | Cw: 16.9374 | T/I = 3.63
# Epc/stp: 2/200 | Lmd = 0.05 | Loss: 0.884  | nnz: 71.47 | train acc.: 0.91 | test acc: 0.92  | mu: 0.0179  | Cw: 17.0640 | T/I = 3.62
# Epc/stp: 2/210 | Lmd = 0.05 | Loss: 0.916  | nnz: 71.64 | train acc.: 0.91 | test acc: 0.91  | mu: 0.0148  | Cw: 17.1932 | T/I = 3.61
# Epc/stp: 2/220 | Lmd = 0.05 | Loss: 0.970  | nnz: 71.97 | train acc.: 0.86 | test acc: 0.91  | mu: 0.0136  | Cw: 17.3224 | T/I = 3.60
# Epc/stp: 2/230 | Lmd = 0.05 | Loss: 0.919  | nnz: 69.62 | train acc.: 0.86 | test acc: 0.91  | mu: 0.0118  | Cw: 17.4507 | T/I = 3.60
# Epc/stp: 2/240 | Lmd = 0.05 | Loss: 0.862  | nnz: 70.41 | train acc.: 0.89 | test acc: 0.91  | mu: 0.0101  | Cw: 17.5803 | T/I = 3.61
# Epc/stp: 2/250 | Lmd = 0.05 | Loss: 0.824  | nnz: 68.69 | train acc.: 0.92 | test acc: 0.91  | mu: 0.0106  | Cw: 17.7100 | T/I = 3.60
# Epc/stp: 2/260 | Lmd = 0.05 | Loss: 0.821  | nnz: 69.59 | train acc.: 0.94 | test acc: 0.91  | mu: 0.0091  | Cw: 17.8360 | T/I = 3.61
# Epc/stp: 2/270 | Lmd = 0.05 | Loss: 0.841  | nnz: 71.31 | train acc.: 0.92 | test acc: 0.92  | mu: 0.0093  | Cw: 17.9571 | T/I = 3.61
# Epc/stp: 2/280 | Lmd = 0.05 | Loss: 0.828  | nnz: 71.50 | train acc.: 0.88 | test acc: 0.92  | mu: 0.0108  | Cw: 18.0789 | T/I = 3.60
# Epc/stp: 2/290 | Lmd = 0.05 | Loss: 0.830  | nnz: 70.23 | train acc.: 0.89 | test acc: 0.92  | mu: 0.0117  | Cw: 18.1999 | T/I = 3.60
# Epc/stp: 2/300 | Lmd = 0.05 | Loss: 0.858  | nnz: 71.77 | train acc.: 0.95 | test acc: 0.92  | mu: 0.0115  | Cw: 18.3230 | T/I = 3.63
# Epc/stp: 2/310 | Lmd = 0.05 | Loss: 0.867  | nnz: 70.16 | train acc.: 0.89 | test acc: 0.92  | mu: 0.0127  | Cw: 18.4432 | T/I = 3.61
# Epc/stp: 2/320 | Lmd = 0.05 | Loss: 0.833  | nnz: 70.83 | train acc.: 0.95 | test acc: 0.92  | mu: 0.0138  | Cw: 18.5623 | T/I = 3.63
# Epc/stp: 2/330 | Lmd = 0.05 | Loss: 0.794  | nnz: 72.00 | train acc.: 0.84 | test acc: 0.92  | mu: 0.0105  | Cw: 18.6759 | T/I = 3.61
# Epc/stp: 2/340 | Lmd = 0.05 | Loss: 0.782  | nnz: 75.16 | train acc.: 0.92 | test acc: 0.92  | mu: 0.0057  | Cw: 18.7926 | T/I = 3.61
# Epc/stp: 2/350 | Lmd = 0.05 | Loss: 0.762  | nnz: 71.89 | train acc.: 0.89 | test acc: 0.92  | mu: 0.0087  | Cw: 18.9060 | T/I = 3.61
# Epc/stp: 2/360 | Lmd = 0.05 | Loss: 0.795  | nnz: 69.45 | train acc.: 0.88 | test acc: 0.92  | mu: 0.0120  | Cw: 19.0222 | T/I = 3.61
# Epc/stp: 2/370 | Lmd = 0.05 | Loss: 0.823  | nnz: 69.67 | train acc.: 0.91 | test acc: 0.92  | mu: 0.0142  | Cw: 19.1370 | T/I = 3.66
# Epc/stp: 2/380 | Lmd = 0.05 | Loss: 0.801  | nnz: 69.78 | train acc.: 0.92 | test acc: 0.92  | mu: 0.0079  | Cw: 19.2450 | T/I = 3.64
# Epc/stp: 2/390 | Lmd = 0.05 | Loss: 0.761  | nnz: 71.38 | train acc.: 0.89 | test acc: 0.92  | mu: 0.0070  | Cw: 19.3539 | T/I = 3.62
# Epc/stp: 2/400 | Lmd = 0.05 | Loss: 0.726  | nnz: 70.53 | train acc.: 0.86 | test acc: 0.92  | mu: 0.0059  | Cw: 19.4657 | T/I = 3.63
# Epc/stp: 2/410 | Lmd = 0.05 | Loss: 0.718  | nnz: 68.91 | train acc.: 0.94 | test acc: 0.92  | mu: 0.0071  | Cw: 19.5727 | T/I = 3.62
# Epc/stp: 2/420 | Lmd = 0.05 | Loss: 0.743  | nnz: 70.94 | train acc.: 0.94 | test acc: 0.92  | mu: 0.0123  | Cw: 19.6724 | T/I = 3.63
# Epc/stp: 2/430 | Lmd = 0.05 | Loss: 0.803  | nnz: 73.02 | train acc.: 0.94 | test acc: 0.92  | mu: 0.0135  | Cw: 19.7755 | T/I = 3.62
# Epc/stp: 2/440 | Lmd = 0.05 | Loss: 0.779  | nnz: 71.02 | train acc.: 0.89 | test acc: 0.92  | mu: 0.0073  | Cw: 19.8791 | T/I = 3.61
# Epc/stp: 2/450 | Lmd = 0.05 | Loss: 0.718  | nnz: 70.33 | train acc.: 0.84 | test acc: 0.92  | mu: 0.0076  | Cw: 19.9797 | T/I = 3.62
# Epc/stp: 2/460 | Lmd = 0.05 | Loss: 0.755  | nnz: 69.84 | train acc.: 0.92 | test acc: 0.92  | mu: 0.0165  | Cw: 20.0866 | T/I = 3.63
# Epc/stp: 2/470 | Lmd = 0.05 | Loss: 0.777  | nnz: 70.84 | train acc.: 0.94 | test acc: 0.92  | mu: 0.0094  | Cw: 20.1913 | T/I = 3.62
# Epc/stp: 2/480 | Lmd = 0.05 | Loss: 0.731  | nnz: 69.98 | train acc.: 0.91 | test acc: 0.92  | mu: 0.0063  | Cw: 20.2936 | T/I = 3.64
# Epc/stp: 2/490 | Lmd = 0.05 | Loss: 0.702  | nnz: 70.61 | train acc.: 0.97 | test acc: 0.92  | mu: 0.0085  | Cw: 20.3963 | T/I = 3.63
# Epc/stp: 2/500 | Lmd = 0.05 | Loss: 0.711  | nnz: 69.83 | train acc.: 0.92 | test acc: 0.93  | mu: 0.0116  | Cw: 20.4961 | T/I = 3.63
# Epc/stp: 2/510 | Lmd = 0.05 | Loss: 0.770  | nnz: 73.55 | train acc.: 0.92 | test acc: 0.93  | mu: 0.0161  | Cw: 20.5917 | T/I = 3.63
# Epc/stp: 2/520 | Lmd = 0.05 | Loss: 0.834  | nnz: 71.12 | train acc.: 0.95 | test acc: 0.93  | mu: 0.0199  | Cw: 20.6854 | T/I = 3.62
# Epc/stp: 2/530 | Lmd = 0.05 | Loss: 0.784  | nnz: 71.84 | train acc.: 0.91 | test acc: 0.93  | mu: 0.0103  | Cw: 20.7876 | T/I = 3.62
# Epc/stp: 2/540 | Lmd = 0.05 | Loss: 0.705  | nnz: 71.25 | train acc.: 0.94 | test acc: 0.93  | mu: 0.0060  | Cw: 20.8933 | T/I = 3.61
# Epc/stp: 2/550 | Lmd = 0.05 | Loss: 0.687  | nnz: 70.62 | train acc.: 0.98 | test acc: 0.93  | mu: 0.0120  | Cw: 20.9940 | T/I = 3.62
# Epc/stp: 2/560 | Lmd = 0.05 | Loss: 0.732  | nnz: 69.92 | train acc.: 0.91 | test acc: 0.93  | mu: 0.0152  | Cw: 21.0876 | T/I = 3.64
# Epc/stp: 2/570 | Lmd = 0.05 | Loss: 0.749  | nnz: 70.78 | train acc.: 0.95 | test acc: 0.93  | mu: 0.0110  | Cw: 21.1829 | T/I = 3.61
# Epc/stp: 2/580 | Lmd = 0.05 | Loss: 0.693  | nnz: 71.95 | train acc.: 0.89 | test acc: 0.93  | mu: 0.0100  | Cw: 21.2745 | T/I = 3.63
# Epc/stp: 2/590 | Lmd = 0.05 | Loss: 0.706  | nnz: 70.97 | train acc.: 0.98 | test acc: 0.93  | mu: 0.0129  | Cw: 21.3558 | T/I = 3.61
# Epc/stp: 2/600 | Lmd = 0.05 | Loss: 0.703  | nnz: 72.75 | train acc.: 0.92 | test acc: 0.93  | mu: 0.0125  | Cw: 21.4386 | T/I = 3.62
# Epc/stp: 2/610 | Lmd = 0.05 | Loss: 0.776  | nnz: 69.83 | train acc.: 0.94 | test acc: 0.93  | mu: 0.0148  | Cw: 21.5236 | T/I = 3.62
# Epc/stp: 2/620 | Lmd = 0.05 | Loss: 0.753  | nnz: 69.23 | train acc.: 0.97 | test acc: 0.93  | mu: 0.0089  | Cw: 21.6148 | T/I = 3.65
# Epc/stp: 2/630 | Lmd = 0.05 | Loss: 0.670  | nnz: 72.88 | train acc.: 0.86 | test acc: 0.93  | mu: 0.0058  | Cw: 21.7061 | T/I = 3.64
# Epc/stp: 2/640 | Lmd = 0.05 | Loss: 0.659  | nnz: 68.84 | train acc.: 0.98 | test acc: 0.93  | mu: 0.0082  | Cw: 21.7932 | T/I = 3.65
# Epc/stp: 2/650 | Lmd = 0.05 | Loss: 0.645  | nnz: 71.67 | train acc.: 0.94 | test acc: 0.93  | mu: 0.0113  | Cw: 21.8854 | T/I = 3.63
# Epc/stp: 2/660 | Lmd = 0.05 | Loss: 0.704  | nnz: 69.53 | train acc.: 0.94 | test acc: 0.93  | mu: 0.0115  | Cw: 21.9743 | T/I = 3.64
# Epc/stp: 2/670 | Lmd = 0.05 | Loss: 0.745  | nnz: 73.33 | train acc.: 0.95 | test acc: 0.93  | mu: 0.0144  | Cw: 22.0641 | T/I = 3.62
# Epc/stp: 2/680 | Lmd = 0.05 | Loss: 0.733  | nnz: 73.22 | train acc.: 0.92 | test acc: 0.93  | mu: 0.0144  | Cw: 22.1549 | T/I = 3.62
# Epc/stp: 2/690 | Lmd = 0.05 | Loss: 0.696  | nnz: 71.92 | train acc.: 0.92 | test acc: 0.93  | mu: 0.0119  | Cw: 22.2438 | T/I = 3.64
# Epc/stp: 2/700 | Lmd = 0.05 | Loss: 0.680  | nnz: 71.28 | train acc.: 0.91 | test acc: 0.93  | mu: 0.0098  | Cw: 22.3348 | T/I = 3.65
# Epc/stp: 2/710 | Lmd = 0.05 | Loss: 0.652  | nnz: 70.58 | train acc.: 0.95 | test acc: 0.93  | mu: 0.0089  | Cw: 22.4249 | T/I = 3.62
# Epc/stp: 2/720 | Lmd = 0.05 | Loss: 0.672  | nnz: 71.12 | train acc.: 0.95 | test acc: 0.93  | mu: 0.0111  | Cw: 22.5065 | T/I = 3.62
# Epc/stp: 2/730 | Lmd = 0.05 | Loss: 0.694  | nnz: 73.17 | train acc.: 0.94 | test acc: 0.93  | mu: 0.0097  | Cw: 22.5915 | T/I = 3.62
# Epc/stp: 2/740 | Lmd = 0.05 | Loss: 0.653  | nnz: 75.20 | train acc.: 0.92 | test acc: 0.93  | mu: 0.0065  | Cw: 22.6752 | T/I = 3.62
# Epc/stp: 2/750 | Lmd = 0.05 | Loss: 0.667  | nnz: 72.44 | train acc.: 0.98 | test acc: 0.93  | mu: 0.0196  | Cw: 22.7585 | T/I = 3.62
# Epc/stp: 2/760 | Lmd = 0.05 | Loss: 0.795  | nnz: 71.89 | train acc.: 0.92 | test acc: 0.93  | mu: 0.0206  | Cw: 22.8407 | T/I = 3.61
# Epc/stp: 2/770 | Lmd = 0.05 | Loss: 0.753  | nnz: 70.62 | train acc.: 0.92 | test acc: 0.93  | mu: 0.0091  | Cw: 22.9175 | T/I = 3.62
# Epc/stp: 2/780 | Lmd = 0.05 | Loss: 0.643  | nnz: 71.98 | train acc.: 0.95 | test acc: 0.93  | mu: 0.0180  | Cw: 22.9974 | T/I = 3.63
# Epc/stp: 2/790 | Lmd = 0.05 | Loss: 0.651  | nnz: 73.83 | train acc.: 0.97 | test acc: 0.93  | mu: 0.0090  | Cw: 23.0775 | T/I = 3.63
# Epc/stp: 2/800 | Lmd = 0.05 | Loss: 0.614  | nnz: 74.86 | train acc.: 0.88 | test acc: 0.93  | mu: 0.0081  | Cw: 23.1530 | T/I = 3.61
# Epc/stp: 2/810 | Lmd = 0.05 | Loss: 0.594  | nnz: 72.00 | train acc.: 0.94 | test acc: 0.93  | mu: 0.0061  | Cw: 23.2305 | T/I = 3.61
# Epc/stp: 2/820 | Lmd = 0.05 | Loss: 0.620  | nnz: 72.67 | train acc.: 0.95 | test acc: 0.93  | mu: 0.0091  | Cw: 23.3038 | T/I = 3.60
# Epc/stp: 2/830 | Lmd = 0.05 | Loss: 0.648  | nnz: 67.80 | train acc.: 0.95 | test acc: 0.93  | mu: 0.0088  | Cw: 23.3753 | T/I = 3.60
# Epc/stp: 2/840 | Lmd = 0.05 | Loss: 0.670  | nnz: 73.92 | train acc.: 0.97 | test acc: 0.93  | mu: 0.0131  | Cw: 23.4483 | T/I = 3.61
# Epc/stp: 2/850 | Lmd = 0.05 | Loss: 0.640  | nnz: 72.70 | train acc.: 0.94 | test acc: 0.93  | mu: 0.0058  | Cw: 23.5186 | T/I = 3.63
# Epc/stp: 2/860 | Lmd = 0.05 | Loss: 0.610  | nnz: 69.69 | train acc.: 0.94 | test acc: 0.93  | mu: 0.0099  | Cw: 23.5909 | T/I = 3.61
# Epc/stp: 2/870 | Lmd = 0.05 | Loss: 0.629  | nnz: 71.11 | train acc.: 0.94 | test acc: 0.93  | mu: 0.0126  | Cw: 23.6631 | T/I = 3.60
# Epc/stp: 2/880 | Lmd = 0.05 | Loss: 0.622  | nnz: 72.78 | train acc.: 0.86 | test acc: 0.93  | mu: 0.0091  | Cw: 23.7289 | T/I = 3.61
# Epc/stp: 2/890 | Lmd = 0.05 | Loss: 0.609  | nnz: 69.20 | train acc.: 0.89 | test acc: 0.93  | mu: 0.0080  | Cw: 23.7949 | T/I = 3.60
# Epc/stp: 2/900 | Lmd = 0.05 | Loss: 0.625  | nnz: 73.06 | train acc.: 0.89 | test acc: 0.93  | mu: 0.0070  | Cw: 23.8637 | T/I = 3.63
# Epc/stp: 2/910 | Lmd = 0.05 | Loss: 0.615  | nnz: 71.98 | train acc.: 0.92 | test acc: 0.94  | mu: 0.0074  | Cw: 23.9287 | T/I = 3.61
# Epc/stp: 2/920 | Lmd = 0.05 | Loss: 0.597  | nnz: 71.23 | train acc.: 0.97 | test acc: 0.94  | mu: 0.0081  | Cw: 23.9947 | T/I = 3.61
# Epc/stp: 2/930 | Lmd = 0.05 | Loss: 0.588  | nnz: 73.44 | train acc.: 0.91 | test acc: 0.94  | mu: 0.0055  | Cw: 24.0632 | T/I = 3.63
# Epc/stp: 3/0 | Lmd = 0.10 | Loss: 0.574  | nnz: 25.31 | train acc.: 0.97 | test acc: 0.93  | mu: 0.0055  | Cw: 24.1173 | T/I = 3.64
# Epc/stp: 3/10 | Lmd = 0.10 | Loss: 0.894  | nnz: 26.27 | train acc.: 0.91 | test acc: 0.93  | mu: 0.0137  | Cw: 24.2073 | T/I = 3.63
# Epc/stp: 3/20 | Lmd = 0.10 | Loss: 1.341  | nnz: 25.69 | train acc.: 0.97 | test acc: 0.94  | mu: 0.0254  | Cw: 24.3100 | T/I = 3.64
# Epc/stp: 3/30 | Lmd = 0.10 | Loss: 2.300  | nnz: 25.58 | train acc.: 0.97 | test acc: 0.93  | mu: 0.0391  | Cw: 24.4127 | T/I = 3.61
# Epc/stp: 3/40 | Lmd = 0.10 | Loss: 3.767  | nnz: 26.41 | train acc.: 0.92 | test acc: 0.93  | mu: 0.0459  | Cw: 24.5159 | T/I = 3.61
# Epc/stp: 3/50 | Lmd = 0.10 | Loss: 4.057  | nnz: 25.80 | train acc.: 0.97 | test acc: 0.93  | mu: 0.0437  | Cw: 24.6169 | T/I = 3.62
# Epc/stp: 3/60 | Lmd = 0.10 | Loss: 3.037  | nnz: 26.08 | train acc.: 0.95 | test acc: 0.93  | mu: 0.0345  | Cw: 24.7185 | T/I = 3.61
# Epc/stp: 3/70 | Lmd = 0.10 | Loss: 1.923  | nnz: 25.31 | train acc.: 0.95 | test acc: 0.93  | mu: 0.0220  | Cw: 24.8193 | T/I = 3.64
# Epc/stp: 3/80 | Lmd = 0.10 | Loss: 1.334  | nnz: 25.28 | train acc.: 0.94 | test acc: 0.93  | mu: 0.0095  | Cw: 24.9210 | T/I = 3.63
# Epc/stp: 3/90 | Lmd = 0.10 | Loss: 1.191  | nnz: 25.36 | train acc.: 0.94 | test acc: 0.93  | mu: 0.0145  | Cw: 25.0281 | T/I = 3.63
# Epc/stp: 3/100 | Lmd = 0.10 | Loss: 1.278  | nnz: 24.25 | train acc.: 0.89 | test acc: 0.93  | mu: 0.0182  | Cw: 25.1350 | T/I = 3.61
# Epc/stp: 3/110 | Lmd = 0.10 | Loss: 1.379  | nnz: 24.38 | train acc.: 0.92 | test acc: 0.93  | mu: 0.0190  | Cw: 25.2392 | T/I = 3.63
# Epc/stp: 3/120 | Lmd = 0.10 | Loss: 1.399  | nnz: 25.00 | train acc.: 0.92 | test acc: 0.93  | mu: 0.0199  | Cw: 25.3404 | T/I = 3.63
# Epc/stp: 3/130 | Lmd = 0.10 | Loss: 1.376  | nnz: 23.84 | train acc.: 0.97 | test acc: 0.93  | mu: 0.0166  | Cw: 25.4364 | T/I = 3.64
# Epc/stp: 3/140 | Lmd = 0.10 | Loss: 1.297  | nnz: 24.30 | train acc.: 0.92 | test acc: 0.93  | mu: 0.0175  | Cw: 25.5248 | T/I = 3.63
# Epc/stp: 3/150 | Lmd = 0.10 | Loss: 1.273  | nnz: 24.03 | train acc.: 0.91 | test acc: 0.93  | mu: 0.0161  | Cw: 25.6162 | T/I = 3.63
# Epc/stp: 3/160 | Lmd = 0.10 | Loss: 1.267  | nnz: 24.06 | train acc.: 0.91 | test acc: 0.93  | mu: 0.0179  | Cw: 25.7099 | T/I = 3.63
# Epc/stp: 3/170 | Lmd = 0.10 | Loss: 1.250  | nnz: 25.64 | train acc.: 0.95 | test acc: 0.93  | mu: 0.0161  | Cw: 25.8005 | T/I = 3.61
# Epc/stp: 3/180 | Lmd = 0.10 | Loss: 1.248  | nnz: 23.61 | train acc.: 0.92 | test acc: 0.93  | mu: 0.0208  | Cw: 25.8881 | T/I = 3.61
# Epc/stp: 3/190 | Lmd = 0.10 | Loss: 1.286  | nnz: 24.83 | train acc.: 0.94 | test acc: 0.93  | mu: 0.0170  | Cw: 25.9743 | T/I = 3.62
# Epc/stp: 3/200 | Lmd = 0.10 | Loss: 1.279  | nnz: 24.72 | train acc.: 0.91 | test acc: 0.93  | mu: 0.0161  | Cw: 26.0601 | T/I = 3.60
# Epc/stp: 3/210 | Lmd = 0.10 | Loss: 1.241  | nnz: 23.88 | train acc.: 0.95 | test acc: 0.93  | mu: 0.0150  | Cw: 26.1467 | T/I = 3.61
# Epc/stp: 3/220 | Lmd = 0.10 | Loss: 1.220  | nnz: 23.78 | train acc.: 0.95 | test acc: 0.93  | mu: 0.0148  | Cw: 26.2259 | T/I = 3.63
# Epc/stp: 3/230 | Lmd = 0.10 | Loss: 1.216  | nnz: 24.69 | train acc.: 0.94 | test acc: 0.93  | mu: 0.0177  | Cw: 26.2982 | T/I = 3.62
# Epc/stp: 3/240 | Lmd = 0.10 | Loss: 1.158  | nnz: 24.39 | train acc.: 0.97 | test acc: 0.93  | mu: 0.0136  | Cw: 26.3715 | T/I = 3.64
# Epc/stp: 3/250 | Lmd = 0.10 | Loss: 1.105  | nnz: 23.67 | train acc.: 0.89 | test acc: 0.93  | mu: 0.0140  | Cw: 26.4461 | T/I = 3.60
# Epc/stp: 3/260 | Lmd = 0.10 | Loss: 1.132  | nnz: 24.45 | train acc.: 0.89 | test acc: 0.93  | mu: 0.0179  | Cw: 26.5210 | T/I = 3.61
# Epc/stp: 3/270 | Lmd = 0.10 | Loss: 1.341  | nnz: 23.62 | train acc.: 0.86 | test acc: 0.93  | mu: 0.0197  | Cw: 26.5949 | T/I = 3.61
# Epc/stp: 3/280 | Lmd = 0.10 | Loss: 1.416  | nnz: 22.67 | train acc.: 0.92 | test acc: 0.93  | mu: 0.0201  | Cw: 26.6656 | T/I = 3.59
# Epc/stp: 3/290 | Lmd = 0.10 | Loss: 1.257  | nnz: 22.03 | train acc.: 0.88 | test acc: 0.93  | mu: 0.0181  | Cw: 26.7321 | T/I = 3.63
# Epc/stp: 3/300 | Lmd = 0.10 | Loss: 1.223  | nnz: 23.55 | train acc.: 0.98 | test acc: 0.93  | mu: 0.0162  | Cw: 26.7992 | T/I = 3.61
# Epc/stp: 3/310 | Lmd = 0.10 | Loss: 1.186  | nnz: 24.55 | train acc.: 0.97 | test acc: 0.93  | mu: 0.0172  | Cw: 26.8646 | T/I = 3.60
# Epc/stp: 3/320 | Lmd = 0.10 | Loss: 1.117  | nnz: 24.36 | train acc.: 0.92 | test acc: 0.93  | mu: 0.0125  | Cw: 26.9272 | T/I = 3.63
# Epc/stp: 3/330 | Lmd = 0.10 | Loss: 1.090  | nnz: 24.08 | train acc.: 0.91 | test acc: 0.93  | mu: 0.0120  | Cw: 26.9908 | T/I = 3.64
# Epc/stp: 3/340 | Lmd = 0.10 | Loss: 1.092  | nnz: 24.38 | train acc.: 0.95 | test acc: 0.93  | mu: 0.0152  | Cw: 27.0524 | T/I = 3.61
# Epc/stp: 3/350 | Lmd = 0.10 | Loss: 1.142  | nnz: 24.03 | train acc.: 0.92 | test acc: 0.93  | mu: 0.0184  | Cw: 27.1071 | T/I = 3.61
# Epc/stp: 3/360 | Lmd = 0.10 | Loss: 1.155  | nnz: 24.89 | train acc.: 0.89 | test acc: 0.93  | mu: 0.0200  | Cw: 27.1609 | T/I = 3.65
# Epc/stp: 3/370 | Lmd = 0.10 | Loss: 1.126  | nnz: 24.31 | train acc.: 0.91 | test acc: 0.93  | mu: 0.0155  | Cw: 27.2127 | T/I = 3.62
# Epc/stp: 3/380 | Lmd = 0.10 | Loss: 1.140  | nnz: 23.47 | train acc.: 0.91 | test acc: 0.93  | mu: 0.0183  | Cw: 27.2659 | T/I = 3.62
# Epc/stp: 3/390 | Lmd = 0.10 | Loss: 1.157  | nnz: 23.56 | train acc.: 0.97 | test acc: 0.93  | mu: 0.0161  | Cw: 27.3230 | T/I = 3.63
# Epc/stp: 3/400 | Lmd = 0.10 | Loss: 1.147  | nnz: 24.61 | train acc.: 0.92 | test acc: 0.93  | mu: 0.0166  | Cw: 27.3790 | T/I = 3.62
# Epc/stp: 3/410 | Lmd = 0.10 | Loss: 1.112  | nnz: 23.20 | train acc.: 0.92 | test acc: 0.93  | mu: 0.0147  | Cw: 27.4324 | T/I = 3.64
# Epc/stp: 3/420 | Lmd = 0.10 | Loss: 1.089  | nnz: 24.23 | train acc.: 0.91 | test acc: 0.93  | mu: 0.0207  | Cw: 27.4807 | T/I = 3.62
# Epc/stp: 3/430 | Lmd = 0.10 | Loss: 1.088  | nnz: 24.47 | train acc.: 0.92 | test acc: 0.93  | mu: 0.0176  | Cw: 27.5376 | T/I = 3.64
# Epc/stp: 3/440 | Lmd = 0.10 | Loss: 1.115  | nnz: 23.94 | train acc.: 0.94 | test acc: 0.93  | mu: 0.0205  | Cw: 27.5907 | T/I = 3.62
# Epc/stp: 3/450 | Lmd = 0.10 | Loss: 1.177  | nnz: 22.88 | train acc.: 0.95 | test acc: 0.93  | mu: 0.0231  | Cw: 27.6371 | T/I = 3.65
# Epc/stp: 3/460 | Lmd = 0.10 | Loss: 1.303  | nnz: 23.48 | train acc.: 0.97 | test acc: 0.93  | mu: 0.0208  | Cw: 27.6840 | T/I = 3.62
# Epc/stp: 3/470 | Lmd = 0.10 | Loss: 1.228  | nnz: 21.58 | train acc.: 0.92 | test acc: 0.93  | mu: 0.0190  | Cw: 27.7343 | T/I = 3.62
# Epc/stp: 3/480 | Lmd = 0.10 | Loss: 1.259  | nnz: 23.28 | train acc.: 0.97 | test acc: 0.93  | mu: 0.0245  | Cw: 27.7899 | T/I = 3.61
# Epc/stp: 3/490 | Lmd = 0.10 | Loss: 1.482  | nnz: 24.23 | train acc.: 0.94 | test acc: 0.93  | mu: 0.0228  | Cw: 27.8351 | T/I = 3.64
# Epc/stp: 3/500 | Lmd = 0.10 | Loss: 1.275  | nnz: 23.38 | train acc.: 0.97 | test acc: 0.93  | mu: 0.0188  | Cw: 27.8739 | T/I = 3.61
# Epc/stp: 3/510 | Lmd = 0.10 | Loss: 1.035  | nnz: 23.31 | train acc.: 0.92 | test acc: 0.93  | mu: 0.0129  | Cw: 27.9141 | T/I = 3.62
# Epc/stp: 3/520 | Lmd = 0.10 | Loss: 1.048  | nnz: 23.44 | train acc.: 0.95 | test acc: 0.93  | mu: 0.0149  | Cw: 27.9592 | T/I = 3.62
# Epc/stp: 3/530 | Lmd = 0.10 | Loss: 1.033  | nnz: 23.05 | train acc.: 0.98 | test acc: 0.93  | mu: 0.0310  | Cw: 28.0040 | T/I = 3.60
# Epc/stp: 3/540 | Lmd = 0.10 | Loss: 1.058  | nnz: 23.42 | train acc.: 0.92 | test acc: 0.93  | mu: 0.0318  | Cw: 28.0456 | T/I = 3.62
# Epc/stp: 3/550 | Lmd = 0.10 | Loss: 1.121  | nnz: 24.31 | train acc.: 0.95 | test acc: 0.93  | mu: 0.0193  | Cw: 28.0898 | T/I = 3.62
# Epc/stp: 3/560 | Lmd = 0.10 | Loss: 1.093  | nnz: 23.20 | train acc.: 0.92 | test acc: 0.93  | mu: 0.0214  | Cw: 28.1309 | T/I = 3.62
# Epc/stp: 3/570 | Lmd = 0.10 | Loss: 1.061  | nnz: 25.05 | train acc.: 0.88 | test acc: 0.93  | mu: 0.0186  | Cw: 28.1694 | T/I = 3.62
# Epc/stp: 3/580 | Lmd = 0.10 | Loss: 1.088  | nnz: 23.28 | train acc.: 0.94 | test acc: 0.93  | mu: 0.0252  | Cw: 28.2072 | T/I = 3.63
# Epc/stp: 3/590 | Lmd = 0.10 | Loss: 1.061  | nnz: 23.69 | train acc.: 0.86 | test acc: 0.93  | mu: 0.0143  | Cw: 28.2527 | T/I = 3.59
# Epc/stp: 3/600 | Lmd = 0.10 | Loss: 1.022  | nnz: 23.44 | train acc.: 0.94 | test acc: 0.93  | mu: 0.0181  | Cw: 28.2939 | T/I = 3.61
# Epc/stp: 3/610 | Lmd = 0.10 | Loss: 1.044  | nnz: 22.50 | train acc.: 0.92 | test acc: 0.93  | mu: 0.0215  | Cw: 28.3279 | T/I = 3.63
# Epc/stp: 3/620 | Lmd = 0.10 | Loss: 1.172  | nnz: 22.52 | train acc.: 0.94 | test acc: 0.93  | mu: 0.0250  | Cw: 28.3634 | T/I = 3.64
# Epc/stp: 3/630 | Lmd = 0.10 | Loss: 1.189  | nnz: 22.80 | train acc.: 0.94 | test acc: 0.93  | mu: 0.0256  | Cw: 28.3947 | T/I = 3.63
# Epc/stp: 3/640 | Lmd = 0.10 | Loss: 1.119  | nnz: 22.28 | train acc.: 0.89 | test acc: 0.93  | mu: 0.0295  | Cw: 28.4226 | T/I = 3.61
# Epc/stp: 3/650 | Lmd = 0.10 | Loss: 1.137  | nnz: 21.64 | train acc.: 0.92 | test acc: 0.93  | mu: 0.0296  | Cw: 28.4530 | T/I = 3.61
# Epc/stp: 3/660 | Lmd = 0.10 | Loss: 1.126  | nnz: 23.05 | train acc.: 0.92 | test acc: 0.93  | mu: 0.0207  | Cw: 28.4836 | T/I = 3.61
# Epc/stp: 3/670 | Lmd = 0.10 | Loss: 1.060  | nnz: 22.64 | train acc.: 0.92 | test acc: 0.93  | mu: 0.0148  | Cw: 28.5128 | T/I = 3.65
# Epc/stp: 3/680 | Lmd = 0.10 | Loss: 1.002  | nnz: 23.03 | train acc.: 0.89 | test acc: 0.93  | mu: 0.0145  | Cw: 28.5439 | T/I = 3.63
# Epc/stp: 3/690 | Lmd = 0.10 | Loss: 0.994  | nnz: 23.39 | train acc.: 0.84 | test acc: 0.93  | mu: 0.0196  | Cw: 28.5674 | T/I = 3.62
# Epc/stp: 3/700 | Lmd = 0.10 | Loss: 1.033  | nnz: 22.67 | train acc.: 0.84 | test acc: 0.93  | mu: 0.0199  | Cw: 28.5948 | T/I = 3.61
# Epc/stp: 3/710 | Lmd = 0.10 | Loss: 1.011  | nnz: 22.92 | train acc.: 0.95 | test acc: 0.93  | mu: 0.0193  | Cw: 28.6201 | T/I = 3.61
# Epc/stp: 3/720 | Lmd = 0.10 | Loss: 0.946  | nnz: 22.75 | train acc.: 0.97 | test acc: 0.93  | mu: 0.0138  | Cw: 28.6503 | T/I = 3.60
# Epc/stp: 3/730 | Lmd = 0.10 | Loss: 0.903  | nnz: 23.05 | train acc.: 0.94 | test acc: 0.93  | mu: 0.0156  | Cw: 28.6751 | T/I = 3.63
# Epc/stp: 3/740 | Lmd = 0.10 | Loss: 0.947  | nnz: 23.48 | train acc.: 0.89 | test acc: 0.93  | mu: 0.0158  | Cw: 28.6983 | T/I = 3.64
# Epc/stp: 3/750 | Lmd = 0.10 | Loss: 1.035  | nnz: 23.56 | train acc.: 0.84 | test acc: 0.93  | mu: 0.0211  | Cw: 28.7265 | T/I = 3.63
# Epc/stp: 3/760 | Lmd = 0.10 | Loss: 1.425  | nnz: 23.44 | train acc.: 0.91 | test acc: 0.93  | mu: 0.0306  | Cw: 28.7496 | T/I = 3.61
# Epc/stp: 3/770 | Lmd = 0.10 | Loss: 1.749  | nnz: 23.20 | train acc.: 0.92 | test acc: 0.93  | mu: 0.0301  | Cw: 28.7713 | T/I = 3.65
# Epc/stp: 3/780 | Lmd = 0.10 | Loss: 1.356  | nnz: 22.56 | train acc.: 0.94 | test acc: 0.93  | mu: 0.0157  | Cw: 28.7964 | T/I = 3.63
# Epc/stp: 3/790 | Lmd = 0.10 | Loss: 0.953  | nnz: 22.91 | train acc.: 0.89 | test acc: 0.93  | mu: 0.0118  | Cw: 28.8200 | T/I = 3.63
# Epc/stp: 3/800 | Lmd = 0.10 | Loss: 0.937  | nnz: 22.56 | train acc.: 0.91 | test acc: 0.93  | mu: 0.0181  | Cw: 28.8397 | T/I = 3.63
# Epc/stp: 3/810 | Lmd = 0.10 | Loss: 0.988  | nnz: 22.55 | train acc.: 0.94 | test acc: 0.93  | mu: 0.0337  | Cw: 28.8583 | T/I = 3.64
# Epc/stp: 3/820 | Lmd = 0.10 | Loss: 0.968  | nnz: 22.64 | train acc.: 0.92 | test acc: 0.93  | mu: 0.0247  | Cw: 28.8800 | T/I = 3.63
# Epc/stp: 3/830 | Lmd = 0.10 | Loss: 0.954  | nnz: 23.09 | train acc.: 0.95 | test acc: 0.93  | mu: 0.0205  | Cw: 28.8937 | T/I = 3.64
# Epc/stp: 3/840 | Lmd = 0.10 | Loss: 1.111  | nnz: 21.77 | train acc.: 0.91 | test acc: 0.93  | mu: 0.0225  | Cw: 28.9137 | T/I = 3.61
# Epc/stp: 3/850 | Lmd = 0.10 | Loss: 1.145  | nnz: 21.25 | train acc.: 0.89 | test acc: 0.93  | mu: 0.0244  | Cw: 28.9327 | T/I = 3.62
# Epc/stp: 3/860 | Lmd = 0.10 | Loss: 1.016  | nnz: 21.89 | train acc.: 0.94 | test acc: 0.93  | mu: 0.0203  | Cw: 28.9518 | T/I = 3.64
# Epc/stp: 3/870 | Lmd = 0.10 | Loss: 1.141  | nnz: 23.05 | train acc.: 0.91 | test acc: 0.93  | mu: 0.0221  | Cw: 28.9692 | T/I = 3.64
# Epc/stp: 3/880 | Lmd = 0.10 | Loss: 1.251  | nnz: 23.73 | train acc.: 0.89 | test acc: 0.93  | mu: 0.0281  | Cw: 28.9915 | T/I = 3.67
# Epc/stp: 3/890 | Lmd = 0.10 | Loss: 1.466  | nnz: 22.88 | train acc.: 0.95 | test acc: 0.93  | mu: 0.0309  | Cw: 29.0125 | T/I = 3.64
# Epc/stp: 3/900 | Lmd = 0.10 | Loss: 1.452  | nnz: 23.11 | train acc.: 0.91 | test acc: 0.93  | mu: 0.0368  | Cw: 29.0292 | T/I = 3.61
# Epc/stp: 3/910 | Lmd = 0.10 | Loss: 1.036  | nnz: 22.66 | train acc.: 0.91 | test acc: 0.93  | mu: 0.0344  | Cw: 29.0395 | T/I = 3.63
# Epc/stp: 3/920 | Lmd = 0.10 | Loss: 0.903  | nnz: 21.59 | train acc.: 0.89 | test acc: 0.93  | mu: 0.0261  | Cw: 29.0569 | T/I = 3.61
# Epc/stp: 3/930 | Lmd = 0.10 | Loss: 1.048  | nnz: 22.00 | train acc.: 0.92 | test acc: 0.93  | mu: 0.0561  | Cw: 29.0766 | T/I = 3.63
# Epc/stp: 4/0 | Lmd = 0.10 | Loss: 1.269  | nnz: 23.38 | train acc.: 0.94 | test acc: 0.93  | mu: 0.0614  | Cw: 29.0894 | T/I = 3.64
# Epc/stp: 4/10 | Lmd = 0.10 | Loss: 1.251  | nnz: 22.97 | train acc.: 0.89 | test acc: 0.93  | mu: 0.0615  | Cw: 29.0999 | T/I = 3.62
# Epc/stp: 4/20 | Lmd = 0.10 | Loss: 0.954  | nnz: 22.06 | train acc.: 0.91 | test acc: 0.93  | mu: 0.0429  | Cw: 29.1126 | T/I = 3.65
# Epc/stp: 4/30 | Lmd = 0.10 | Loss: 0.873  | nnz: 22.78 | train acc.: 1.00 | test acc: 0.93  | mu: 0.0429  | Cw: 29.1243 | T/I = 3.62
# Epc/stp: 4/40 | Lmd = 0.10 | Loss: 0.894  | nnz: 21.64 | train acc.: 0.92 | test acc: 0.93  | mu: 0.0349  | Cw: 29.1361 | T/I = 3.61
# Epc/stp: 4/50 | Lmd = 0.10 | Loss: 0.943  | nnz: 23.36 | train acc.: 0.92 | test acc: 0.93  | mu: 0.0361  | Cw: 29.1434 | T/I = 3.61
# Epc/stp: 4/60 | Lmd = 0.10 | Loss: 0.961  | nnz: 22.72 | train acc.: 0.95 | test acc: 0.93  | mu: 0.0477  | Cw: 29.1546 | T/I = 3.61
# Epc/stp: 4/70 | Lmd = 0.10 | Loss: 0.879  | nnz: 22.11 | train acc.: 0.89 | test acc: 0.93  | mu: 0.0224  | Cw: 29.1706 | T/I = 3.62
# Epc/stp: 4/80 | Lmd = 0.10 | Loss: 0.978  | nnz: 22.58 | train acc.: 0.92 | test acc: 0.93  | mu: 0.0502  | Cw: 29.1810 | T/I = 3.62
# Epc/stp: 4/90 | Lmd = 0.10 | Loss: 1.286  | nnz: 23.19 | train acc.: 0.98 | test acc: 0.93  | mu: 0.0670  | Cw: 29.1910 | T/I = 3.61
# Epc/stp: 4/100 | Lmd = 0.10 | Loss: 1.149  | nnz: 23.58 | train acc.: 0.92 | test acc: 0.93  | mu: 0.0523  | Cw: 29.2066 | T/I = 3.66
# Epc/stp: 4/110 | Lmd = 0.10 | Loss: 0.865  | nnz: 22.36 | train acc.: 0.89 | test acc: 0.93  | mu: 0.0202  | Cw: 29.2179 | T/I = 3.61
# Epc/stp: 4/120 | Lmd = 0.10 | Loss: 0.802  | nnz: 22.70 | train acc.: 0.94 | test acc: 0.93  | mu: 0.0281  | Cw: 29.2322 | T/I = 3.63
# Epc/stp: 4/130 | Lmd = 0.10 | Loss: 0.807  | nnz: 22.69 | train acc.: 0.92 | test acc: 0.93  | mu: 0.0314  | Cw: 29.2487 | T/I = 3.60
# Epc/stp: 4/140 | Lmd = 0.10 | Loss: 0.819  | nnz: 22.39 | train acc.: 0.92 | test acc: 0.93  | mu: 0.0295  | Cw: 29.2685 | T/I = 3.61
# Epc/stp: 4/150 | Lmd = 0.10 | Loss: 0.872  | nnz: 23.06 | train acc.: 0.95 | test acc: 0.93  | mu: 0.0342  | Cw: 29.2916 | T/I = 3.64
# Epc/stp: 4/160 | Lmd = 0.10 | Loss: 0.889  | nnz: 22.47 | train acc.: 0.94 | test acc: 0.93  | mu: 0.0424  | Cw: 29.3089 | T/I = 3.58
# Epc/stp: 4/170 | Lmd = 0.10 | Loss: 0.844  | nnz: 22.84 | train acc.: 0.92 | test acc: 0.93  | mu: 0.0276  | Cw: 29.3319 | T/I = 3.60
# Epc/stp: 4/180 | Lmd = 0.10 | Loss: 0.854  | nnz: 22.77 | train acc.: 0.91 | test acc: 0.93  | mu: 0.0360  | Cw: 29.3499 | T/I = 3.64
# Epc/stp: 4/190 | Lmd = 0.10 | Loss: 0.918  | nnz: 22.61 | train acc.: 0.97 | test acc: 0.94  | mu: 0.0264  | Cw: 29.3614 | T/I = 3.63
# Epc/stp: 4/200 | Lmd = 0.10 | Loss: 0.890  | nnz: 22.00 | train acc.: 0.89 | test acc: 0.94  | mu: 0.0172  | Cw: 29.3722 | T/I = 3.62
# Epc/stp: 4/210 | Lmd = 0.10 | Loss: 0.865  | nnz: 23.00 | train acc.: 0.97 | test acc: 0.94  | mu: 0.0190  | Cw: 29.3836 | T/I = 3.62
# Epc/stp: 4/220 | Lmd = 0.10 | Loss: 0.875  | nnz: 22.80 | train acc.: 0.97 | test acc: 0.93  | mu: 0.0228  | Cw: 29.3961 | T/I = 3.62
# Epc/stp: 4/230 | Lmd = 0.10 | Loss: 0.849  | nnz: 23.66 | train acc.: 0.92 | test acc: 0.94  | mu: 0.0166  | Cw: 29.4064 | T/I = 3.61
# Epc/stp: 4/240 | Lmd = 0.10 | Loss: 0.813  | nnz: 22.98 | train acc.: 0.89 | test acc: 0.94  | mu: 0.0137  | Cw: 29.4132 | T/I = 3.62
# Epc/stp: 4/250 | Lmd = 0.10 | Loss: 0.827  | nnz: 22.58 | train acc.: 0.86 | test acc: 0.94  | mu: 0.0148  | Cw: 29.4234 | T/I = 3.62
# Epc/stp: 4/260 | Lmd = 0.10 | Loss: 0.822  | nnz: 22.77 | train acc.: 0.97 | test acc: 0.94  | mu: 0.0176  | Cw: 29.4371 | T/I = 3.64
# Epc/stp: 4/270 | Lmd = 0.10 | Loss: 0.865  | nnz: 22.27 | train acc.: 0.98 | test acc: 0.93  | mu: 0.0253  | Cw: 29.4510 | T/I = 3.64
# Epc/stp: 4/280 | Lmd = 0.10 | Loss: 0.941  | nnz: 23.59 | train acc.: 0.94 | test acc: 0.93  | mu: 0.0231  | Cw: 29.4539 | T/I = 3.64
# Epc/stp: 4/290 | Lmd = 0.10 | Loss: 0.896  | nnz: 22.42 | train acc.: 0.94 | test acc: 0.94  | mu: 0.0288  | Cw: 29.4549 | T/I = 3.64
# Epc/stp: 4/300 | Lmd = 0.10 | Loss: 0.866  | nnz: 23.22 | train acc.: 0.92 | test acc: 0.94  | mu: 0.0255  | Cw: 29.4579 | T/I = 3.65
# Epc/stp: 4/310 | Lmd = 0.10 | Loss: 0.899  | nnz: 22.19 | train acc.: 0.95 | test acc: 0.94  | mu: 0.0204  | Cw: 29.4634 | T/I = 3.62
# Epc/stp: 4/320 | Lmd = 0.10 | Loss: 0.846  | nnz: 22.20 | train acc.: 0.95 | test acc: 0.94  | mu: 0.0191  | Cw: 29.4700 | T/I = 3.61
# Epc/stp: 4/330 | Lmd = 0.10 | Loss: 0.803  | nnz: 21.67 | train acc.: 0.97 | test acc: 0.94  | mu: 0.0205  | Cw: 29.4803 | T/I = 3.60
# Epc/stp: 4/340 | Lmd = 0.10 | Loss: 1.142  | nnz: 22.86 | train acc.: 0.91 | test acc: 0.94  | mu: 0.0279  | Cw: 29.4877 | T/I = 3.60
# Epc/stp: 4/350 | Lmd = 0.10 | Loss: 1.331  | nnz: 22.78 | train acc.: 0.98 | test acc: 0.94  | mu: 0.0272  | Cw: 29.4983 | T/I = 3.61
# Epc/stp: 4/360 | Lmd = 0.10 | Loss: 0.948  | nnz: 22.58 | train acc.: 0.95 | test acc: 0.94  | mu: 0.0155  | Cw: 29.5104 | T/I = 3.60
# Epc/stp: 4/370 | Lmd = 0.10 | Loss: 0.813  | nnz: 21.73 | train acc.: 0.97 | test acc: 0.94  | mu: 0.0166  | Cw: 29.5206 | T/I = 3.60
# Epc/stp: 4/380 | Lmd = 0.10 | Loss: 0.888  | nnz: 22.39 | train acc.: 0.95 | test acc: 0.94  | mu: 0.0223  | Cw: 29.5336 | T/I = 3.60
# Epc/stp: 4/390 | Lmd = 0.10 | Loss: 0.939  | nnz: 21.55 | train acc.: 0.94 | test acc: 0.94  | mu: 0.0289  | Cw: 29.5436 | T/I = 3.60
# Epc/stp: 4/400 | Lmd = 0.10 | Loss: 0.967  | nnz: 22.52 | train acc.: 0.97 | test acc: 0.94  | mu: 0.0166  | Cw: 29.5529 | T/I = 3.63
# Epc/stp: 4/410 | Lmd = 0.10 | Loss: 0.863  | nnz: 22.50 | train acc.: 0.91 | test acc: 0.94  | mu: 0.0178  | Cw: 29.5606 | T/I = 3.61
# Epc/stp: 4/420 | Lmd = 0.10 | Loss: 0.788  | nnz: 21.67 | train acc.: 0.95 | test acc: 0.93  | mu: 0.0110  | Cw: 29.5701 | T/I = 3.61
# Epc/stp: 4/430 | Lmd = 0.10 | Loss: 0.777  | nnz: 22.56 | train acc.: 0.92 | test acc: 0.94  | mu: 0.0127  | Cw: 29.5733 | T/I = 3.61
# Epc/stp: 4/440 | Lmd = 0.10 | Loss: 0.780  | nnz: 22.75 | train acc.: 0.94 | test acc: 0.94  | mu: 0.0135  | Cw: 29.5763 | T/I = 3.61
# Epc/stp: 4/450 | Lmd = 0.10 | Loss: 0.792  | nnz: 23.09 | train acc.: 0.91 | test acc: 0.94  | mu: 0.0108  | Cw: 29.5819 | T/I = 3.61
# Epc/stp: 4/460 | Lmd = 0.10 | Loss: 0.805  | nnz: 22.09 | train acc.: 0.84 | test acc: 0.94  | mu: 0.0147  | Cw: 29.5891 | T/I = 3.62
# Epc/stp: 4/470 | Lmd = 0.10 | Loss: 0.813  | nnz: 21.41 | train acc.: 0.95 | test acc: 0.94  | mu: 0.0111  | Cw: 29.5970 | T/I = 3.61
# Epc/stp: 4/480 | Lmd = 0.10 | Loss: 0.770  | nnz: 21.52 | train acc.: 0.95 | test acc: 0.94  | mu: 0.0122  | Cw: 29.6006 | T/I = 3.61
# Epc/stp: 4/490 | Lmd = 0.10 | Loss: 0.735  | nnz: 22.83 | train acc.: 0.89 | test acc: 0.94  | mu: 0.0082  | Cw: 29.5982 | T/I = 3.61
# Epc/stp: 4/500 | Lmd = 0.10 | Loss: 0.739  | nnz: 21.70 | train acc.: 0.91 | test acc: 0.94  | mu: 0.0153  | Cw: 29.6066 | T/I = 3.63
# Epc/stp: 4/510 | Lmd = 0.10 | Loss: 0.788  | nnz: 21.33 | train acc.: 0.97 | test acc: 0.94  | mu: 0.0193  | Cw: 29.6151 | T/I = 3.64
# Epc/stp: 4/520 | Lmd = 0.10 | Loss: 0.788  | nnz: 22.02 | train acc.: 0.94 | test acc: 0.94  | mu: 0.0145  | Cw: 29.6271 | T/I = 3.63
# Epc/stp: 4/530 | Lmd = 0.10 | Loss: 0.762  | nnz: 21.23 | train acc.: 0.95 | test acc: 0.94  | mu: 0.0157  | Cw: 29.6333 | T/I = 3.64
# Epc/stp: 4/540 | Lmd = 0.10 | Loss: 0.789  | nnz: 22.84 | train acc.: 0.92 | test acc: 0.94  | mu: 0.0127  | Cw: 29.6385 | T/I = 3.62
# Epc/stp: 4/550 | Lmd = 0.10 | Loss: 0.822  | nnz: 21.75 | train acc.: 0.97 | test acc: 0.94  | mu: 0.0125  | Cw: 29.6359 | T/I = 3.61
# Epc/stp: 4/560 | Lmd = 0.10 | Loss: 0.760  | nnz: 22.83 | train acc.: 0.91 | test acc: 0.94  | mu: 0.0144  | Cw: 29.6367 | T/I = 3.64
# Epc/stp: 4/570 | Lmd = 0.10 | Loss: 0.730  | nnz: 22.19 | train acc.: 0.97 | test acc: 0.94  | mu: 0.0152  | Cw: 29.6394 | T/I = 3.59
# Epc/stp: 4/580 | Lmd = 0.10 | Loss: 0.767  | nnz: 22.38 | train acc.: 0.97 | test acc: 0.94  | mu: 0.0167  | Cw: 29.6475 | T/I = 3.60
# Epc/stp: 4/590 | Lmd = 0.10 | Loss: 0.783  | nnz: 21.47 | train acc.: 0.94 | test acc: 0.94  | mu: 0.0180  | Cw: 29.6546 | T/I = 3.61
# Epc/stp: 4/600 | Lmd = 0.10 | Loss: 0.843  | nnz: 21.69 | train acc.: 0.92 | test acc: 0.94  | mu: 0.0173  | Cw: 29.6576 | T/I = 3.59
# Epc/stp: 4/610 | Lmd = 0.10 | Loss: 0.812  | nnz: 22.06 | train acc.: 0.92 | test acc: 0.94  | mu: 0.0110  | Cw: 29.6581 | T/I = 3.63
# Epc/stp: 4/620 | Lmd = 0.10 | Loss: 0.729  | nnz: 22.08 | train acc.: 0.95 | test acc: 0.94  | mu: 0.0127  | Cw: 29.6628 | T/I = 3.62
# Epc/stp: 4/630 | Lmd = 0.10 | Loss: 0.742  | nnz: 22.80 | train acc.: 0.88 | test acc: 0.94  | mu: 0.0164  | Cw: 29.6643 | T/I = 3.62
# Epc/stp: 4/640 | Lmd = 0.10 | Loss: 0.784  | nnz: 21.72 | train acc.: 0.92 | test acc: 0.94  | mu: 0.0133  | Cw: 29.6661 | T/I = 3.60
# Epc/stp: 4/650 | Lmd = 0.10 | Loss: 0.745  | nnz: 22.45 | train acc.: 0.92 | test acc: 0.94  | mu: 0.0108  | Cw: 29.6718 | T/I = 3.62
# Epc/stp: 4/660 | Lmd = 0.10 | Loss: 0.660  | nnz: 22.31 | train acc.: 0.95 | test acc: 0.94  | mu: 0.0070  | Cw: 29.6761 | T/I = 3.62
# Epc/stp: 4/670 | Lmd = 0.10 | Loss: 0.665  | nnz: 21.67 | train acc.: 0.95 | test acc: 0.94  | mu: 0.0124  | Cw: 29.6820 | T/I = 3.62
# Epc/stp: 4/680 | Lmd = 0.10 | Loss: 0.729  | nnz: 22.12 | train acc.: 0.92 | test acc: 0.94  | mu: 0.0182  | Cw: 29.6843 | T/I = 3.65
# Epc/stp: 4/690 | Lmd = 0.10 | Loss: 0.793  | nnz: 22.36 | train acc.: 0.92 | test acc: 0.94  | mu: 0.0189  | Cw: 29.6889 | T/I = 3.63
# Epc/stp: 4/700 | Lmd = 0.10 | Loss: 0.779  | nnz: 21.59 | train acc.: 0.95 | test acc: 0.94  | mu: 0.0103  | Cw: 29.6893 | T/I = 3.62
# Epc/stp: 4/710 | Lmd = 0.10 | Loss: 0.723  | nnz: 21.66 | train acc.: 0.94 | test acc: 0.94  | mu: 0.0108  | Cw: 29.6993 | T/I = 3.61
# Epc/stp: 4/720 | Lmd = 0.10 | Loss: 0.739  | nnz: 22.45 | train acc.: 0.94 | test acc: 0.94  | mu: 0.0112  | Cw: 29.7074 | T/I = 3.62
# Epc/stp: 4/730 | Lmd = 0.10 | Loss: 0.782  | nnz: 22.58 | train acc.: 0.91 | test acc: 0.94  | mu: 0.0179  | Cw: 29.7146 | T/I = 3.64
# ...
# Epc/stp: 35/0 | Lmd = 0.20 | Loss: 0.535  | nnz: 4.78 | train acc.: 0.94 | test acc: 0.93  | mu: 0.0103  | Cw: 35.1252 | T/I = 3.63
# Epc/stp: 35/10 | Lmd = 0.20 | Loss: 0.544  | nnz: 5.17 | train acc.: 0.95 | test acc: 0.93  | mu: 0.0146  | Cw: 35.1260 | T/I = 3.64
# Epc/stp: 35/20 | Lmd = 0.20 | Loss: 0.566  | nnz: 4.95 | train acc.: 0.95 | test acc: 0.93  | mu: 0.0128  | Cw: 35.1248 | T/I = 3.64
# Epc/stp: 35/30 | Lmd = 0.20 | Loss: 0.595  | nnz: 4.78 | train acc.: 0.91 | test acc: 0.93  | mu: 0.0214  | Cw: 35.1237 | T/I = 3.66
# Epc/stp: 35/40 | Lmd = 0.20 | Loss: 0.619  | nnz: 4.56 | train acc.: 0.95 | test acc: 0.93  | mu: 0.0193  | Cw: 35.1242 | T/I = 3.67
# Epc/stp: 35/50 | Lmd = 0.20 | Loss: 0.634  | nnz: 4.72 | train acc.: 0.94 | test acc: 0.93  | mu: 0.0151  | Cw: 35.1268 | T/I = 3.65
# Epc/stp: 35/60 | Lmd = 0.20 | Loss: 0.611  | nnz: 4.75 | train acc.: 0.94 | test acc: 0.93  | mu: 0.0143  | Cw: 35.1289 | T/I = 3.64
# Epc/stp: 35/70 | Lmd = 0.20 | Loss: 0.579  | nnz: 5.02 | train acc.: 0.92 | test acc: 0.93  | mu: 0.0158  | Cw: 35.1296 | T/I = 3.64
# Epc/stp: 35/80 | Lmd = 0.20 | Loss: 0.648  | nnz: 4.73 | train acc.: 0.92 | test acc: 0.93  | mu: 0.0162  | Cw: 35.1292 | T/I = 3.66
# Epc/stp: 35/90 | Lmd = 0.20 | Loss: 0.748  | nnz: 4.91 | train acc.: 0.95 | test acc: 0.93  | mu: 0.0159  | Cw: 35.1293 | T/I = 3.64
# Epc/stp: 35/100 | Lmd = 0.20 | Loss: 0.751  | nnz: 4.52 | train acc.: 0.98 | test acc: 0.93  | mu: 0.0138  | Cw: 35.1305 | T/I = 3.64
# Epc/stp: 35/110 | Lmd = 0.20 | Loss: 0.657  | nnz: 5.03 | train acc.: 0.92 | test acc: 0.93  | mu: 0.0134  | Cw: 35.1328 | T/I = 3.67
# Epc/stp: 35/120 | Lmd = 0.20 | Loss: 0.593  | nnz: 4.69 | train acc.: 0.94 | test acc: 0.93  | mu: 0.0100  | Cw: 35.1338 | T/I = 3.67
# Epc/stp: 35/130 | Lmd = 0.20 | Loss: 0.563  | nnz: 4.78 | train acc.: 0.92 | test acc: 0.93  | mu: 0.0110  | Cw: 35.1347 | T/I = 3.64
# Epc/stp: 35/140 | Lmd = 0.20 | Loss: 0.551  | nnz: 4.72 | train acc.: 0.91 | test acc: 0.93  | mu: 0.0109  | Cw: 35.1354 | T/I = 3.66
# Epc/stp: 35/150 | Lmd = 0.20 | Loss: 0.532  | nnz: 4.92 | train acc.: 0.97 | test acc: 0.93  | mu: 0.0087  | Cw: 35.1364 | T/I = 3.66
# Epc/stp: 35/160 | Lmd = 0.20 | Loss: 0.515  | nnz: 4.69 | train acc.: 0.95 | test acc: 0.93  | mu: 0.0121  | Cw: 35.1363 | T/I = 3.65
# Epc/stp: 35/170 | Lmd = 0.20 | Loss: 0.526  | nnz: 4.92 | train acc.: 0.89 | test acc: 0.93  | mu: 0.0157  | Cw: 35.1359 | T/I = 3.65
# Epc/stp: 35/180 | Lmd = 0.20 | Loss: 0.544  | nnz: 4.94 | train acc.: 0.92 | test acc: 0.93  | mu: 0.0122  | Cw: 35.1352 | T/I = 3.66
# Epc/stp: 35/190 | Lmd = 0.20 | Loss: 0.550  | nnz: 4.67 | train acc.: 0.92 | test acc: 0.93  | mu: 0.0116  | Cw: 35.1350 | T/I = 3.64
# Epc/stp: 35/200 | Lmd = 0.20 | Loss: 0.536  | nnz: 4.64 | train acc.: 0.97 | test acc: 0.93  | mu: 0.0097  | Cw: 35.1362 | T/I = 3.64
# Epc/stp: 35/210 | Lmd = 0.20 | Loss: 0.538  | nnz: 4.66 | train acc.: 0.91 | test acc: 0.93  | mu: 0.0121  | Cw: 35.1365 | T/I = 3.64
# Epc/stp: 35/220 | Lmd = 0.20 | Loss: 0.622  | nnz: 5.20 | train acc.: 0.86 | test acc: 0.93  | mu: 0.0138  | Cw: 35.1375 | T/I = 3.67
# Epc/stp: 35/230 | Lmd = 0.20 | Loss: 0.663  | nnz: 5.23 | train acc.: 0.98 | test acc: 0.93  | mu: 0.0143  | Cw: 35.1390 | T/I = 3.65
# Epc/stp: 35/240 | Lmd = 0.20 | Loss: 0.572  | nnz: 4.77 | train acc.: 0.97 | test acc: 0.93  | mu: 0.0120  | Cw: 35.1398 | T/I = 3.65
# Epc/stp: 35/250 | Lmd = 0.20 | Loss: 0.519  | nnz: 4.69 | train acc.: 0.95 | test acc: 0.93  | mu: 0.0104  | Cw: 35.1399 | T/I = 3.66
# Epc/stp: 35/260 | Lmd = 0.20 | Loss: 0.526  | nnz: 4.59 | train acc.: 0.92 | test acc: 0.93  | mu: 0.0117  | Cw: 35.1401 | T/I = 3.65
# Epc/stp: 35/270 | Lmd = 0.20 | Loss: 0.534  | nnz: 4.98 | train acc.: 0.94 | test acc: 0.93  | mu: 0.0077  | Cw: 35.1403 | T/I = 3.64
# Epc/stp: 35/280 | Lmd = 0.20 | Loss: 0.535  | nnz: 4.86 | train acc.: 0.92 | test acc: 0.93  | mu: 0.0118  | Cw: 35.1416 | T/I = 3.68
# Epc/stp: 35/290 | Lmd = 0.20 | Loss: 0.555  | nnz: 4.39 | train acc.: 0.94 | test acc: 0.93  | mu: 0.0151  | Cw: 35.1419 | T/I = 3.67
# Epc/stp: 35/300 | Lmd = 0.20 | Loss: 0.599  | nnz: 4.78 | train acc.: 0.94 | test acc: 0.93  | mu: 0.0177  | Cw: 35.1407 | T/I = 3.64
# Epc/stp: 35/310 | Lmd = 0.20 | Loss: 0.649  | nnz: 4.95 | train acc.: 0.89 | test acc: 0.93  | mu: 0.0167  | Cw: 35.1380 | T/I = 3.64
# Epc/stp: 35/320 | Lmd = 0.20 | Loss: 0.644  | nnz: 4.73 | train acc.: 0.89 | test acc: 0.93  | mu: 0.0153  | Cw: 35.1374 | T/I = 3.62
# Epc/stp: 35/330 | Lmd = 0.20 | Loss: 0.612  | nnz: 4.91 | train acc.: 0.97 | test acc: 0.93  | mu: 0.0129  | Cw: 35.1371 | T/I = 3.66
# Epc/stp: 35/340 | Lmd = 0.20 | Loss: 0.577  | nnz: 4.48 | train acc.: 0.97 | test acc: 0.93  | mu: 0.0122  | Cw: 35.1353 | T/I = 3.64
# Epc/stp: 35/350 | Lmd = 0.20 | Loss: 0.565  | nnz: 4.62 | train acc.: 0.91 | test acc: 0.93  | mu: 0.0106  | Cw: 35.1333 | T/I = 3.66
# Epc/stp: 35/360 | Lmd = 0.20 | Loss: 0.556  | nnz: 4.88 | train acc.: 0.92 | test acc: 0.93  | mu: 0.0104  | Cw: 35.1320 | T/I = 3.65
# Epc/stp: 35/370 | Lmd = 0.20 | Loss: 0.556  | nnz: 4.69 | train acc.: 0.94 | test acc: 0.93  | mu: 0.0097  | Cw: 35.1305 | T/I = 3.66
# Epc/stp: 35/380 | Lmd = 0.20 | Loss: 0.535  | nnz: 4.70 | train acc.: 0.89 | test acc: 0.93  | mu: 0.0135  | Cw: 35.1285 | T/I = 3.64
# Epc/stp: 35/390 | Lmd = 0.20 | Loss: 0.541  | nnz: 4.95 | train acc.: 0.98 | test acc: 0.93  | mu: 0.0177  | Cw: 35.1270 | T/I = 3.66
# Epc/stp: 35/400 | Lmd = 0.20 | Loss: 0.585  | nnz: 4.78 | train acc.: 0.95 | test acc: 0.93  | mu: 0.0142  | Cw: 35.1274 | T/I = 3.67
# Epc/stp: 35/410 | Lmd = 0.20 | Loss: 0.584  | nnz: 4.80 | train acc.: 0.89 | test acc: 0.93  | mu: 0.0134  | Cw: 35.1274 | T/I = 3.65
# Epc/stp: 35/420 | Lmd = 0.20 | Loss: 0.559  | nnz: 4.77 | train acc.: 0.97 | test acc: 0.93  | mu: 0.0113  | Cw: 35.1284 | T/I = 3.67
# Epc/stp: 35/430 | Lmd = 0.20 | Loss: 0.554  | nnz: 4.81 | train acc.: 0.94 | test acc: 0.93  | mu: 0.0083  | Cw: 35.1297 | T/I = 3.66
# Epc/stp: 35/440 | Lmd = 0.20 | Loss: 0.541  | nnz: 4.69 | train acc.: 0.95 | test acc: 0.93  | mu: 0.0085  | Cw: 35.1295 | T/I = 3.66
# Epc/stp: 35/450 | Lmd = 0.20 | Loss: 0.528  | nnz: 4.95 | train acc.: 0.95 | test acc: 0.93  | mu: 0.0093  | Cw: 35.1297 | T/I = 3.67
# Epc/stp: 35/460 | Lmd = 0.20 | Loss: 0.535  | nnz: 4.72 | train acc.: 0.92 | test acc: 0.93  | mu: 0.0084  | Cw: 35.1293 | T/I = 3.65
# Epc/stp: 35/470 | Lmd = 0.20 | Loss: 0.560  | nnz: 5.12 | train acc.: 0.91 | test acc: 0.93  | mu: 0.0109  | Cw: 35.1290 | T/I = 3.64
# Epc/stp: 35/480 | Lmd = 0.20 | Loss: 0.576  | nnz: 4.83 | train acc.: 0.94 | test acc: 0.93  | mu: 0.0106  | Cw: 35.1307 | T/I = 3.63
# Epc/stp: 35/490 | Lmd = 0.20 | Loss: 0.564  | nnz: 4.73 | train acc.: 0.92 | test acc: 0.93  | mu: 0.0117  | Cw: 35.1307 | T/I = 3.64
# Epc/stp: 35/500 | Lmd = 0.20 | Loss: 0.588  | nnz: 4.94 | train acc.: 0.97 | test acc: 0.93  | mu: 0.0146  | Cw: 35.1287 | T/I = 3.64
# Epc/stp: 35/510 | Lmd = 0.20 | Loss: 0.645  | nnz: 5.02 | train acc.: 0.92 | test acc: 0.93  | mu: 0.0173  | Cw: 35.1274 | T/I = 3.65
# Epc/stp: 35/520 | Lmd = 0.20 | Loss: 0.723  | nnz: 4.67 | train acc.: 0.97 | test acc: 0.93  | mu: 0.0187  | Cw: 35.1270 | T/I = 3.67
# Epc/stp: 35/530 | Lmd = 0.20 | Loss: 0.713  | nnz: 4.64 | train acc.: 0.95 | test acc: 0.93  | mu: 0.0176  | Cw: 35.1280 | T/I = 3.64
# Epc/stp: 35/540 | Lmd = 0.20 | Loss: 0.645  | nnz: 4.62 | train acc.: 0.86 | test acc: 0.93  | mu: 0.0139  | Cw: 35.1283 | T/I = 3.67
# Epc/stp: 35/550 | Lmd = 0.20 | Loss: 0.585  | nnz: 4.91 | train acc.: 0.97 | test acc: 0.93  | mu: 0.0162  | Cw: 35.1288 | T/I = 3.64
# Epc/stp: 35/560 | Lmd = 0.20 | Loss: 0.549  | nnz: 4.66 | train acc.: 0.97 | test acc: 0.93  | mu: 0.0131  | Cw: 35.1298 | T/I = 3.66
# Epc/stp: 35/570 | Lmd = 0.20 | Loss: 0.566  | nnz: 4.45 | train acc.: 0.91 | test acc: 0.93  | mu: 0.0175  | Cw: 35.1320 | T/I = 3.65
# Epc/stp: 35/580 | Lmd = 0.20 | Loss: 0.574  | nnz: 4.69 | train acc.: 0.94 | test acc: 0.93  | mu: 0.0120  | Cw: 35.1335 | T/I = 3.64
# Epc/stp: 35/590 | Lmd = 0.20 | Loss: 0.577  | nnz: 5.12 | train acc.: 0.97 | test acc: 0.93  | mu: 0.0140  | Cw: 35.1348 | T/I = 3.64
# Epc/stp: 35/600 | Lmd = 0.20 | Loss: 0.583  | nnz: 5.09 | train acc.: 0.91 | test acc: 0.93  | mu: 0.0142  | Cw: 35.1360 | T/I = 3.68
# Epc/stp: 35/610 | Lmd = 0.20 | Loss: 0.564  | nnz: 4.78 | train acc.: 0.91 | test acc: 0.93  | mu: 0.0147  | Cw: 35.1349 | T/I = 3.65
# Epc/stp: 35/620 | Lmd = 0.20 | Loss: 0.554  | nnz: 4.69 | train acc.: 0.91 | test acc: 0.93  | mu: 0.0153  | Cw: 35.1343 | T/I = 3.68
# Epc/stp: 35/630 | Lmd = 0.20 | Loss: 0.567  | nnz: 4.84 | train acc.: 0.92 | test acc: 0.93  | mu: 0.0099  | Cw: 35.1331 | T/I = 3.66
# Epc/stp: 35/640 | Lmd = 0.20 | Loss: 0.573  | nnz: 4.78 | train acc.: 0.98 | test acc: 0.93  | mu: 0.0132  | Cw: 35.1327 | T/I = 3.66
# Epc/stp: 35/650 | Lmd = 0.20 | Loss: 0.566  | nnz: 4.95 | train acc.: 0.94 | test acc: 0.93  | mu: 0.0182  | Cw: 35.1307 | T/I = 3.64
# Epc/stp: 35/660 | Lmd = 0.20 | Loss: 0.556  | nnz: 4.83 | train acc.: 0.92 | test acc: 0.93  | mu: 0.0133  | Cw: 35.1287 | T/I = 3.66
# Epc/stp: 35/670 | Lmd = 0.20 | Loss: 0.545  | nnz: 4.92 | train acc.: 0.94 | test acc: 0.93  | mu: 0.0186  | Cw: 35.1285 | T/I = 3.64
# Epc/stp: 35/680 | Lmd = 0.20 | Loss: 0.558  | nnz: 4.86 | train acc.: 0.91 | test acc: 0.93  | mu: 0.0223  | Cw: 35.1285 | T/I = 3.64
# Epc/stp: 35/690 | Lmd = 0.20 | Loss: 0.588  | nnz: 4.98 | train acc.: 0.89 | test acc: 0.93  | mu: 0.0140  | Cw: 35.1294 | T/I = 3.65
# Epc/stp: 35/700 | Lmd = 0.20 | Loss: 0.569  | nnz: 4.83 | train acc.: 0.91 | test acc: 0.93  | mu: 0.0106  | Cw: 35.1305 | T/I = 3.64
# Epc/stp: 35/710 | Lmd = 0.20 | Loss: 0.549  | nnz: 4.64 | train acc.: 0.95 | test acc: 0.93  | mu: 0.0141  | Cw: 35.1285 | T/I = 3.68
# Epc/stp: 35/720 | Lmd = 0.20 | Loss: 0.582  | nnz: 4.55 | train acc.: 0.92 | test acc: 0.93  | mu: 0.0117  | Cw: 35.1287 | T/I = 3.66
# Epc/stp: 35/730 | Lmd = 0.20 | Loss: 0.592  | nnz: 5.22 | train acc.: 0.94 | test acc: 0.93  | mu: 0.0081  | Cw: 35.1293 | T/I = 3.64
# Epc/stp: 35/740 | Lmd = 0.20 | Loss: 0.583  | nnz: 5.06 | train acc.: 0.86 | test acc: 0.93  | mu: 0.0189  | Cw: 35.1295 | T/I = 3.67
# Epc/stp: 35/750 | Lmd = 0.20 | Loss: 0.589  | nnz: 4.88 | train acc.: 0.88 | test acc: 0.93  | mu: 0.0136  | Cw: 35.1296 | T/I = 3.67
# Epc/stp: 35/760 | Lmd = 0.20 | Loss: 0.557  | nnz: 4.88 | train acc.: 0.97 | test acc: 0.93  | mu: 0.0115  | Cw: 35.1291 | T/I = 3.66
# Epc/stp: 35/770 | Lmd = 0.20 | Loss: 0.559  | nnz: 4.98 | train acc.: 0.94 | test acc: 0.93  | mu: 0.0108  | Cw: 35.1275 | T/I = 3.65
# Epc/stp: 35/780 | Lmd = 0.20 | Loss: 0.582  | nnz: 4.88 | train acc.: 0.89 | test acc: 0.93  | mu: 0.0115  | Cw: 35.1280 | T/I = 3.66
# Epc/stp: 35/790 | Lmd = 0.20 | Loss: 0.607  | nnz: 5.05 | train acc.: 0.92 | test acc: 0.93  | mu: 0.0158  | Cw: 35.1285 | T/I = 3.64
# Epc/stp: 35/800 | Lmd = 0.20 | Loss: 0.584  | nnz: 4.91 | train acc.: 0.98 | test acc: 0.93  | mu: 0.0105  | Cw: 35.1291 | T/I = 3.64
# Epc/stp: 35/810 | Lmd = 0.20 | Loss: 0.518  | nnz: 4.89 | train acc.: 0.88 | test acc: 0.93  | mu: 0.0122  | Cw: 35.1298 | T/I = 3.60
# Epc/stp: 35/820 | Lmd = 0.20 | Loss: 0.535  | nnz: 4.72 | train acc.: 0.98 | test acc: 0.93  | mu: 0.0124  | Cw: 35.1303 | T/I = 3.64
# Epc/stp: 35/830 | Lmd = 0.20 | Loss: 0.559  | nnz: 5.16 | train acc.: 0.88 | test acc: 0.93  | mu: 0.0106  | Cw: 35.1301 | T/I = 3.64
# Epc/stp: 35/840 | Lmd = 0.20 | Loss: 0.576  | nnz: 4.83 | train acc.: 0.97 | test acc: 0.93  | mu: 0.0144  | Cw: 35.1301 | T/I = 3.66
# Epc/stp: 35/850 | Lmd = 0.20 | Loss: 0.547  | nnz: 4.89 | train acc.: 0.92 | test acc: 0.93  | mu: 0.0145  | Cw: 35.1302 | T/I = 3.65
# Epc/stp: 35/860 | Lmd = 0.20 | Loss: 0.546  | nnz: 5.05 | train acc.: 0.86 | test acc: 0.93  | mu: 0.0129  | Cw: 35.1300 | T/I = 3.64
# Epc/stp: 35/870 | Lmd = 0.20 | Loss: 0.568  | nnz: 4.70 | train acc.: 0.91 | test acc: 0.93  | mu: 0.0164  | Cw: 35.1303 | T/I = 3.64
# Epc/stp: 35/880 | Lmd = 0.20 | Loss: 0.575  | nnz: 4.70 | train acc.: 0.94 | test acc: 0.93  | mu: 0.0162  | Cw: 35.1297 | T/I = 3.64
# Epc/stp: 35/890 | Lmd = 0.20 | Loss: 0.582  | nnz: 4.73 | train acc.: 0.94 | test acc: 0.93  | mu: 0.0131  | Cw: 35.1300 | T/I = 3.65
# Epc/stp: 35/900 | Lmd = 0.20 | Loss: 0.584  | nnz: 4.53 | train acc.: 0.97 | test acc: 0.93  | mu: 0.0105  | Cw: 35.1304 | T/I = 3.66
# Epc/stp: 35/910 | Lmd = 0.20 | Loss: 0.578  | nnz: 4.83 | train acc.: 0.91 | test acc: 0.93  | mu: 0.0112  | Cw: 35.1313 | T/I = 3.65
# Epc/stp: 35/920 | Lmd = 0.20 | Loss: 0.573  | nnz: 5.22 | train acc.: 0.92 | test acc: 0.93  | mu: 0.0130  | Cw: 35.1324 | T/I = 3.65
# Epc/stp: 35/930 | Lmd = 0.20 | Loss: 0.588  | nnz: 4.73 | train acc.: 0.95 | test acc: 0.93  | mu: 0.0154  | Cw: 35.1316 | T/I = 3.68
# Epc/stp: 36/0 | Lmd = 0.20 | Loss: 0.613  | nnz: 5.17 | train acc.: 0.95 | test acc: 0.93  | mu: 0.0159  | Cw: 35.1317 | T/I = 3.65
# Epc/stp: 36/10 | Lmd = 0.20 | Loss: 0.593  | nnz: 5.05 | train acc.: 0.95 | test acc: 0.93  | mu: 0.0192  | Cw: 35.1312 | T/I = 3.67
# Epc/stp: 36/20 | Lmd = 0.20 | Loss: 0.582  | nnz: 4.97 | train acc.: 0.95 | test acc: 0.93  | mu: 0.0168  | Cw: 35.1310 | T/I = 3.65
# Epc/stp: 36/30 | Lmd = 0.20 | Loss: 0.577  | nnz: 5.09 | train acc.: 0.95 | test acc: 0.93  | mu: 0.0130  | Cw: 35.1313 | T/I = 3.65
# Epc/stp: 36/40 | Lmd = 0.20 | Loss: 0.561  | nnz: 4.92 | train acc.: 0.97 | test acc: 0.93  | mu: 0.0101  | Cw: 35.1316 | T/I = 3.65
# Epc/stp: 36/50 | Lmd = 0.20 | Loss: 0.564  | nnz: 4.97 | train acc.: 0.89 | test acc: 0.93  | mu: 0.0094  | Cw: 35.1322 | T/I = 3.69
# Epc/stp: 36/60 | Lmd = 0.20 | Loss: 0.567  | nnz: 4.86 | train acc.: 0.95 | test acc: 0.93  | mu: 0.0109  | Cw: 35.1326 | T/I = 3.68
# Epc/stp: 36/70 | Lmd = 0.20 | Loss: 0.561  | nnz: 4.77 | train acc.: 0.91 | test acc: 0.93  | mu: 0.0111  | Cw: 35.1344 | T/I = 3.64
# Epc/stp: 36/80 | Lmd = 0.20 | Loss: 0.580  | nnz: 4.66 | train acc.: 0.94 | test acc: 0.93  | mu: 0.0139  | Cw: 35.1346 | T/I = 3.66
# Epc/stp: 36/90 | Lmd = 0.20 | Loss: 0.599  | nnz: 4.98 | train acc.: 0.92 | test acc: 0.93  | mu: 0.0126  | Cw: 35.1336 | T/I = 3.66
# Epc/stp: 36/100 | Lmd = 0.20 | Loss: 0.621  | nnz: 5.05 | train acc.: 0.92 | test acc: 0.93  | mu: 0.0142  | Cw: 35.1334 | T/I = 3.65
# Epc/stp: 36/110 | Lmd = 0.20 | Loss: 0.603  | nnz: 5.08 | train acc.: 0.94 | test acc: 0.93  | mu: 0.0141  | Cw: 35.1324 | T/I = 3.66
# Epc/stp: 36/120 | Lmd = 0.20 | Loss: 0.574  | nnz: 4.81 | train acc.: 0.88 | test acc: 0.93  | mu: 0.0178  | Cw: 35.1318 | T/I = 3.65
# Epc/stp: 36/130 | Lmd = 0.20 | Loss: 0.576  | nnz: 4.95 | train acc.: 0.89 | test acc: 0.93  | mu: 0.0219  | Cw: 35.1321 | T/I = 3.65
# Epc/stp: 36/140 | Lmd = 0.20 | Loss: 0.566  | nnz: 4.67 | train acc.: 0.91 | test acc: 0.93  | mu: 0.0150  | Cw: 35.1331 | T/I = 3.64
# Epc/stp: 36/150 | Lmd = 0.20 | Loss: 0.566  | nnz: 4.62 | train acc.: 0.95 | test acc: 0.93  | mu: 0.0095  | Cw: 35.1337 | T/I = 3.65
# Epc/stp: 36/160 | Lmd = 0.20 | Loss: 0.564  | nnz: 4.64 | train acc.: 0.92 | test acc: 0.93  | mu: 0.0151  | Cw: 35.1322 | T/I = 3.64
# Epc/stp: 36/170 | Lmd = 0.20 | Loss: 0.585  | nnz: 5.08 | train acc.: 0.97 | test acc: 0.93  | mu: 0.0149  | Cw: 35.1322 | T/I = 3.66
# Epc/stp: 36/180 | Lmd = 0.20 | Loss: 0.574  | nnz: 4.88 | train acc.: 0.92 | test acc: 0.93  | mu: 0.0129  | Cw: 35.1323 | T/I = 3.65
# Epc/stp: 36/190 | Lmd = 0.20 | Loss: 0.563  | nnz: 4.95 | train acc.: 0.94 | test acc: 0.93  | mu: 0.0129  | Cw: 35.1321 | T/I = 3.66
# Epc/stp: 36/200 | Lmd = 0.20 | Loss: 0.545  | nnz: 5.05 | train acc.: 0.95 | test acc: 0.93  | mu: 0.0092  | Cw: 35.1329 | T/I = 3.68
# Epc/stp: 36/210 | Lmd = 0.20 | Loss: 0.547  | nnz: 4.94 | train acc.: 0.89 | test acc: 0.93  | mu: 0.0092  | Cw: 35.1335 | T/I = 3.67
# Epc/stp: 36/220 | Lmd = 0.20 | Loss: 0.574  | nnz: 4.92 | train acc.: 0.92 | test acc: 0.93  | mu: 0.0121  | Cw: 35.1340 | T/I = 3.67
# Epc/stp: 36/230 | Lmd = 0.20 | Loss: 0.581  | nnz: 5.02 | train acc.: 0.91 | test acc: 0.93  | mu: 0.0127  | Cw: 35.1342 | T/I = 3.64
# Epc/stp: 36/240 | Lmd = 0.20 | Loss: 0.572  | nnz: 4.81 | train acc.: 0.97 | test acc: 0.93  | mu: 0.0105  | Cw: 35.1348 | T/I = 3.64

# %%
# torch.save(model.state_dict(), 'models/mnist_model_L02.tr')
# model.load_state_dict(torch.load('models/mnist_model.tr'))

from skimage import data, color
from skimage.transform import rescale, resize, downscale_local_mean
    
plt.style.use('ggplot')

plt.figure(figsize=(15,5))
plt.subplot(1,3,1)
plt.plot(Loss_sup); plt.title('Loss'); plt.xlabel('mini-bach / dict update');
plt.subplot(1,3,2)
plt.plot(accuracy_test); plt.title('Test Accuracy'); plt.xlabel('mini-bach / dict update');
plt.subplot(1,3,3)
plt.plot(nnz); plt.title('NNZ per sample'); plt.xlabel('mini-bach / dict update');
plt.show()

plt.figure(figsize=(6,6))
# plt.subplot(1,2,1)
# W1 = model.cpu().W.data.numpy().copy()
# M1 = modelDL.showFilters(W1,10,10)
# plt.imshow(rescale(M1,4,mode='constant'),cmap='gray')
# plt.title('Unsupervised')
# plt.subplot(1,2,2)
model_ = model
W2 = model_.W.data.cpu().numpy().copy()
M2 = modelDL.showFilters(W2,nat,nat)
plt.imshow(rescale(M2,4,mode='constant'),cmap='gray')
plt.title('Supervised')
plt.axis('off')
plt.show()
# Out:
# /home/jere/anaconda3/lib/python3.7/site-packages/skimage/transform/_warps.py:23: UserWarning: The default multichannel argument (None) is deprecated.  Please specify either True or False explicitly.  multichannel will default to False starting with release 0.16.
#   warn('The default multichannel argument (None) is deprecated.  Please '

# %% [markdown]
# ### Adversarial Attack and Analysis

# %%
# Step 5: Evaluate the ART classifier on benign test examples
_, test_loader = get_data_loaders(data_dir,200)
model.learn_flag = False


(x, y) = next(iter(test_loader))
b_x = preprocess(x).to(device).type(model.W.type())

min_pixel_value = torch.min(x)
max_pixel_value = torch.max(x)
criterion = nn.CrossEntropyLoss()
n = 28**2

classifier = PyTorchClassifier(
    model=model,
    clip_values=(min_pixel_value, max_pixel_value),
    loss=criterion,
    optimizer='',
    input_shape=(1,n),
    nb_classes=10,
)

predictions = classifier.predict(b_x)
Acc_0 = np.sum(np.argmax(predictions, axis=1) == (y.numpy())) / len(y)
print("Accuracy on benign test examples: {}%".format(Acc_0 * 100))
# Out:
# Accuracy on benign test examples: 95.5%

# %% [markdown]
# Analizing Margins

# %%
importlib.reload(modelDL)

model.to(device)
(Accs,mrgns) = modelDL.getSoftMargin(model,b_x,y)
Cw = modelDL.get_ClassifierConstant(model)

Target_Accuracy = .6
target_margin = mrgns[np.where(Accs<Target_Accuracy)[0][0]-1]

plt.plot(mrgns,Accs,'.')
plt.plot(target_margin,Target_Accuracy,'x')
plt.xlabel('margin')
plt.ylabel('accuracy')
plt.title('Accuracy vs Soft Margin')
plt.show()

print('Target Accuracy %.2f at Margin = %.4f'%(Target_Accuracy,target_margin))
# Out:
# Target Accuracy 0.60 at Margin = 2.5999

# %%
importlib.reload(modelDL)

mus = modelDL.get_babel(model)
Max_S = torch.sum(mus<1)

model.to(device)
print('Maximum sparsity: %d'%(Max_S))
tests = np.zeros(Max_S)
_,projs = modelDL.get_encoderGap(model,b_x,1)
for i in range(Max_S):
    s = i
    gap = projs[s]
    B1 = gap / 2
    B2 = target_margin / Cw * torch.sqrt(1-mus[s])
    tests[i] = min(B1.cpu(),B2.float())
# Out:
# Maximum sparsity: 255

# %%
sbest = np.argmax(tests)
print('Best s = %d'%(sbest+1))
s = sbest
gap = projs[s]

plt.figure(figsize=(7,3))
plt.subplot(1,2,1)
plt.plot(projs.cpu().numpy())
plt.title('Encoder Gap')
plt.xlabel('s')

plt.subplot(1,2,2)
plt.plot(tests)
plt.title('Best Bound')
plt.xlabel('s')

B1 = gap / 2
B2 = target_margin / Cw * torch.sqrt(1-mus[s])
Bound = min(B1.cpu(),B2.float())
print('Bounds: B1 = %.4f, B2 = %.4f'%(B1,B2))
# Out:
# Best s = 38
# Bounds: B1 = 0.0642, B2 = 0.0642

# %% [markdown]
# Analyzing Cerified Accuracy and comparing with Randomized Smoothing

# %%
importlib.reload(modelDL)
from art.wrappers.randomized_smoothing import *

model_d = model.double()
model.lambd = model.lambd.double()

classifier_rs = PyTorchClassifier(
    model=model_d,
    clip_values=(min_pixel_value, max_pixel_value),
    loss=criterion,
    optimizer='',
    input_shape=(1,n),
    nb_classes=10,
)

n_samples = 100
SIGMAS = np.linspace(0.001,.1,5)

Certified_Acc = []
Certified_Rad = []

distances = np.linspace(0,0.15,12)

for i in range(len(SIGMAS)):
    r_smoothed = RandomizedSmoothing(classifier,n_samples,scale = SIGMAS[i],alpha=.0001)
    (a,b) = r_smoothed.certify(b_x.double(), n_samples)
    Acc = np.zeros(len(distances))
    for j in range(len(distances)):
        Acc[j] = np.sum( (a == y.numpy()) & (b >= distances[j])) / len(y)
        
    Certified_Acc.append(Acc)
    Certified_Rad.append(distances)

# %%
for i in range(len(Certified_Rad)):
    plt.plot(Certified_Rad[i],Certified_Acc[i],label=SIGMAS[i])
plt.legend()
plt.ylabel('Certified Accuracy')
plt.xlabel('Certified Radius')
# Out:
# Text(0.5, 0, 'Certified Radius')

# %% [markdown]
# Certified Accuracy with our bounds

# %%
model.float()
(Accs,mrgns) = modelDL.getSoftMargin(model,b_x,y)
# plt.plot(mrgns,Accs)

mus = modelDL.get_babel(model)
Max_S = torch.sum(mus<1)
print('Maximum sparsity: %d'%(Max_S))

Certified_Acc_sparse = []
Certified_Rad_sparse = []
Certified_s_sparse = []

# testing encoder Gaps at different sparsity levels
gap,projs = modelDL.get_encoderGap(model,b_x,s)

B1 = projs / 2  # encoder gap as a function of sparsity


for i in range(len(mrgns)):
    target_margin = mrgns[i]
    tests = np.zeros(Max_S)
    for j in range(1,Max_S):
        B2 = target_margin / Cw * torch.sqrt(1-mus[s-1])
        tests[j] = min(B1[j].cpu(),B2.float())
    
    Certified_s_sparse.append(np.argmax(tests))
    Certified_Rad_sparse.append(np.max(tests))
    Certified_Acc_sparse.append(Accs[i])
# Out:
# Maximum sparsity: 255

# %%
plt.style.use('bmh')
plt.figure(figsize=(4,4))
plt.plot(Certified_Rad_sparse,Certified_Acc_sparse,label = 'Our bound')
for i in range(len(Certified_Rad)):
    plt.plot(Certified_Rad[i],Certified_Acc[i],'--',label=r'$\sigma$ = %.2f'%np.round(SIGMAS[i],2))
plt.legend()
plt.ylabel('Certified Accuracy')
plt.xlabel('Certified Radius')
plt.ylim([0,1])
plt.savefig('CertAcc_L02_trans.pdf',transparent = True,dpi = 100)
